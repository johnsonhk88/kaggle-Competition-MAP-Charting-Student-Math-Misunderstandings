# %% [markdown]
# # Kaggle Competition Info
# In this competition, you’ll develop an NLP model driven by ML to accurately predict students’ potential math misconceptions based on student explanations in open-ended responses. This solution will suggest candidate misconceptions for these explanations, making it easier for teachers to identify and address students’ incorrect thinking, which is critical to improving student math learning.
# ## Offical Link
# https://www.kaggle.com/competitions/map-charting-student-math-misunderstandings

# %% [markdown]
# # Recommand install package first at Add-ons --> Install Dependence
#
# ```python
# !pip install -U bitsandbytes==0.47.0
# !pip install -U peft==0.17.0
# !pip install -U trl==0.21.0
# !pip install -U accelerate==1.10.0
# !pip install transformers==4.55.0
# !pip install langchain==0.3.27
# !pip install -U langchain-core==0.3.74
# !pip install langchain-text-splitters==0.3.9
# !pip install langchain-community==0.3.27
# !pip install -U deepeval==3.3.9
# ```

# %% [markdown]
# ## install package for local only, unsloth offical docker not need install

# %%
# import kagglehub

DEBUG = True #True

if DEBUG is True:
    # !pip install --upgrade datasets accelerate  # add datasets, accelerate , bitsndbytes
    # !pip install -U peft==0.14.0
    # !pip install -U trl==0.11.4
    # # !pip install --upgrade peft trl
    # # !pip install -U datasets
    # !pip install -U accelerate==1.0.1
    # !pip install transformers==4.45.2
    # !pip install langchain==0.3.27
    # !pip install -U langchain-core==0.3.74
    # !pip install langchain-text-splitters==0.3.9
    # !pip install langchain-community==0.3.27
    # # !pip install -U deepeval==3.3.9
    # # !pip install protobuf==4.25.8 #4.49.0     # 6.30.2      #==3.20.3 #4.49.0
    # # !pip install triton==3.0.0   # avoid load LLM error
    # !pip install bitsandbytes==0.46.1
    # # !pip install unsloth==2025.9.9
    # !pip install unsloth==2025.9.1
    # !pip install --upgrade datasets accelerate  # add datasets, accelerate , bitsndbytes
    # !pip install -U peft==0.14.0
    # !pip install -U trl==0.11.4
    # !pip install --upgrade peft trl
    # !pip install -U datasets
    # !pip install -U accelerate==1.0.1
    # !pip install -U transformers==4.45.2
    # !pip install -U langchain==0.3.27
    # !pip install -U langchain-core==0.3.74
    # !pip install -U langchain-text-splitters==0.3.9
    # !pip install -U langchain-community==0.3.27
    # !pip install -U deepeval==3.3.9
    # !pip install protobuf==4.25.8 #4.49.0     # 6.30.2      #==3.20.3 #4.49.0
    # !pip install triton==3.0.0   # avoid load LLM error
    # !pip install -U bitsandbytes==0.46.1
    # !pip install unsloth==2025.9.9
    # !pip install -U unsloth===2024.9
    # !pip install -U unsloth-zoo==2024.11.0 
    # !pip install -U xformers==0.0.27.post2
    # !pip install -U vllm==0.6.2 #vllm==0.6.6
    # !pip install huggingface_hub==0.24.7
    # !pip install "huggingface_hub>=0.34.0"
    # !pip uninstall unsloth -y
    # !pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
    # !pip install -U unsloth-zoo

else:
    # package = kagglehub.package_import("/johnsonhk88/universal-llm-install-package2")
    # installDir = "/kaggle/input/universal-llm-install-package2/V7" #"/kaggle/input/universal-llm-install-package2/V7"
    installDir = "/kaggle/input/universal-llm-install-package2/V9"
    # installDir2 ="/kaggle/input/deepeval-open-source-llm-evaluation-framework"
    # !pip install transformers --no-index --no-deps --find-links=file://{installDir}/transformers-4.45.2-py3-none-any.whl
    # !pip install -U accelerate --no-index --no-deps --find-links=file://{installDir}/accelerate-1.0.1-py3-none-any.whl
    # !pip install -U trl --no-index --no-deps --find-links=file://{installDir}/trl-0.11.4-py3-none-any.whl
    # !pip install -U peft --no-index --no-deps --find-links=file://{installDir}/peft-0.14.0-py3-none-any.whl
    # !pip install  bitsandbytes --no-index --no-deps --find-links=file://{installDir}/bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl
    
    # !pip install -U langchain --no-index  --no-deps --find-links=file://{installDir}/langchain-0.3.3-py3-none-any.whl
    # !pip install -U langchain_core --no-index  --no-deps --find-links=file://{installDir}/langchain_core-0.3.12-py3-none-any.whl
    # !pip install -U langchain_text_splitters  --no-index  --no-deps  --find-links=file://{installDir}/langchain_text_splitters-0.3.0-py3-none-any.whl
    # !pip install -U langchain_community  --no-index  --no-deps   --find-links=file://{installDir}/langchain_community-0.3.2-py3-none-any.whl
    # !pip install -U triton  --no-index --no-deps  --find-links=file://{installDir}/triton-3.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
    # !pip install -U protobuf  --no-index  --no-deps  --find-links=file://{installDir}/protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl  
    
    # !pip install -U vllm   --no-index --find-links=file:///kaggle/input/vllm-inference/
# Out:
# Requirement already satisfied: peft==0.14.0 in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (7.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (2.4.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (4.56.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (1.0.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (0.5.3)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.14.0) (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->peft==0.14.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->peft==0.14.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->peft==0.14.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->peft==0.14.0) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->peft==0.14.0) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->peft==0.14.0) (2.4.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.14.0) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft==0.14.0) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.14.0) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.14.0) (0.22.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft==0.14.0) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->peft==0.14.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->peft==0.14.0) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->peft==0.14.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->peft==0.14.0) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft==0.14.0) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.13.0->peft==0.14.0) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->peft==0.14.0) (2024.2.0)
# Requirement already satisfied: trl==0.11.4 in /usr/local/lib/python3.11/dist-packages (0.11.4)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from trl==0.11.4) (2.4.0)
# Requirement already satisfied: transformers>=4.40.0 in /usr/local/lib/python3.11/dist-packages (from trl==0.11.4) (4.56.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from trl==0.11.4) (1.0.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from trl==0.11.4) (3.6.0)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.11/dist-packages (from trl==0.11.4) (0.9.32)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.11/dist-packages (from trl==0.11.4) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.2->trl==0.11.4) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.2->trl==0.11.4) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.2->trl==0.11.4) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.2->trl==0.11.4) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.2->trl==0.11.4) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.2->trl==0.11.4) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (4.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4.0->trl==0.11.4) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl==0.11.4) (12.4.127)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (0.35.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.40.0->trl==0.11.4) (4.67.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.5.11->trl==0.11.4) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.5.11->trl==0.11.4) (14.0.0)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.5.11->trl==0.11.4) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro>=0.5.11->trl==0.11.4) (4.4.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->trl==0.11.4) (7.0.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->trl==0.11.4) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->trl==0.11.4) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->trl==0.11.4) (2.2.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->trl==0.11.4) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->trl==0.11.4) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (3.12.13)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.40.0->trl==0.11.4) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.40.0->trl==0.11.4) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.40.0->trl==0.11.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.40.0->trl==0.11.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.40.0->trl==0.11.4) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.11.4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.11.4) (2.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.4.0->trl==0.11.4) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.2->trl==0.11.4) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.2->trl==0.11.4) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.2->trl==0.11.4) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.2->trl==0.11.4) (2024.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->trl==0.11.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->trl==0.11.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->trl==0.11.4) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.4.0->trl==0.11.4) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->trl==0.11.4) (1.20.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.2->trl==0.11.4) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.11.4) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->trl==0.11.4) (1.17.0)
# Requirement already satisfied: accelerate==1.0.1 in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (7.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (0.35.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.0.1) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.0.1) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.0.1) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.0.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.0.1) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.0.1) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.0.1) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate==1.0.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate==1.0.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate==1.0.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate==1.0.1) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate==1.0.1) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate==1.0.1) (2.4.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate==1.0.1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==1.0.1) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10.0->accelerate==1.0.1) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate==1.0.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate==1.0.1) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0.0,>=1.17->accelerate==1.0.1) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0.0,>=1.17->accelerate==1.0.1) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.0.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.0.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.0.1) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.10.0->accelerate==1.0.1) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0.0,>=1.17->accelerate==1.0.1) (2024.2.0)
# Collecting transformers==4.45.2
#   Using cached transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (0.5.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.2)
#   Using cached tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.45.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.45.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.45.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.45.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.45.2) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.45.2) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.45.2) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.45.2) (2025.6.15)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.45.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.45.2) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.45.2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.45.2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.45.2) (2024.2.0)
# Using cached transformers-4.45.2-py3-none-any.whl (9.9 MB)
# Using cached tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed tokenizers-0.20.3 transformers-4.45.2
# Requirement already satisfied: langchain==0.3.27 in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (0.3.74)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (0.4.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.27) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (4.14.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain==0.3.27) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.27) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.27) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.27) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.27) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.27) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.27) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain==0.3.27) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.27) (1.3.1)
# Requirement already satisfied: langchain-core==0.3.74 in /usr/local/lib/python3.11/dist-packages (0.3.74)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (0.4.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (4.14.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain-core==0.3.74) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.3.74) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core==0.3.74) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core==0.3.74) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core==0.3.74) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core==0.3.74) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core==0.3.74) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core==0.3.74) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core==0.3.74) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core==0.3.74) (0.4.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core==0.3.74) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core==0.3.74) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core==0.3.74) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core==0.3.74) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core==0.3.74) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core==0.3.74) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core==0.3.74) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core==0.3.74) (1.3.1)
# Requirement already satisfied: langchain-text-splitters==0.3.9 in /usr/local/lib/python3.11/dist-packages (0.3.9)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain-text-splitters==0.3.9) (0.3.74)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (0.4.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (4.14.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (0.4.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-text-splitters==0.3.9) (1.3.1)
# Requirement already satisfied: langchain-community==0.3.27 in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (0.3.74)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (2.11.0)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (0.4.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.27) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.27) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.27) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community==0.3.27) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community==0.3.27) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community==0.3.27) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community==0.3.27) (4.14.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community==0.3.27) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community==0.3.27) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community==0.3.27) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community==0.3.27) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community==0.3.27) (0.23.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community==0.3.27) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community==0.3.27) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community==0.3.27) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community==0.3.27) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community==0.3.27) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community==0.3.27) (2.4.1)
# ...
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.20.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch<3,>=2.2->bitsandbytes>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 194.6 MB/s eta 0:00:000:00:01
# Downloading unsloth_zoo-2025.9.14-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.5/256.5 kB 328.5 MB/s eta 0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 300.8 MB/s eta 0:00:00
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2025.9.11-py3-none-any.whl size=318122 sha256=f3ac747755a37950461550be11da0f61cfa93cfec408a260903b4c62202d6c2a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ttw06o4f/wheels/d1/17/05/850ab10c33284a4763b0595cd8ea9d01fce6e221cac24b3c01
# Successfully built unsloth
# Installing collected packages: unsloth, tokenizers, transformers, unsloth_zoo
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.45.2
#     Uninstalling transformers-4.45.2:
#       Successfully uninstalled transformers-4.45.2
#   Attempting uninstall: unsloth_zoo
#     Found existing installation: unsloth_zoo 2024.11.0
#     Uninstalling unsloth_zoo-2024.11.0:
#       Successfully uninstalled unsloth_zoo-2024.11.0
# Successfully installed tokenizers-0.22.1 transformers-4.56.2 unsloth-2025.9.11 unsloth_zoo-2025.9.14
# Requirement already satisfied: unsloth-zoo in /usr/local/lib/python3.11/dist-packages (2025.9.14)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (2.4.0)
# Requirement already satisfied: torchao in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.10.0)
# Requirement already satisfied: triton in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (3.0.0)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (25.0)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.9.32)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (4.56.2)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (7.0.0)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (1.0.1)
# Requirement already satisfied: trl!=0.15.0,!=0.19.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.23.0,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.11.4)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.14.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (3.20.3)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.35.3)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.1.9)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (11.2.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (2024.11.6)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (0.19.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from unsloth-zoo) (3.18.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth-zoo) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth-zoo) (0.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.34.0->unsloth-zoo) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->unsloth-zoo) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->unsloth-zoo) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->unsloth-zoo) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->unsloth-zoo) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->unsloth-zoo) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->unsloth-zoo) (2.4.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth-zoo) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.4.0->unsloth-zoo) (12.4.127)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.56.2,>=4.51.3->unsloth-zoo) (0.22.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth-zoo) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth-zoo) (14.0.0)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth-zoo) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth-zoo) (4.4.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (3.12.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro->unsloth-zoo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro->unsloth-zoo) (2.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.4.0->unsloth-zoo) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->unsloth-zoo) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->unsloth-zoo) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->unsloth-zoo) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->unsloth-zoo) (2024.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=2.4.0->unsloth-zoo) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (1.20.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->unsloth-zoo) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth-zoo) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,>=3.4.1->unsloth-zoo) (1.17.0)

# %%
# !pip install unsloth==2025.9.9
# import torch
# torch.__version__

# %%
# !pip install deepspeed==0.14.5
# import tensorflow as tf
# tf.__version__

# %%
# !pip install -U unsloth-zoo==2024.11.0

# %%
from huggingface_hub.utils import get_token

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import os, time , gc , json
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# import seaborn as sns

import torch
from torch import nn
import transformers

# from 
from unsloth import FastLanguageModel
import torch
# Out:
# /tmp/ipykernel_3863/3404414432.py:17: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 10-05 10:38:11 [__init__.py:244] Automatically detected platform cuda.

# %%
import trl
trl.__version__
# Out:
# '0.19.1'

# %%
import torch
from sklearn.model_selection import train_test_split

from transformers import (AutoTokenizer, 
                          BitsAndBytesConfig, 
                          AutoModelForCausalLM,
                          AutoModelForSequenceClassification,
                         TrainingArguments)

from datasets import Dataset, DatasetDict, load_dataset


# Fine tuning 
from trl import SFTTrainer, SFTConfig
from peft import (LoraConfig, 
                    PeftModel, 
                    get_peft_model)
                    # prepare_model_for_kbit_training)  #prepare_model_for_int8_training deprecated 

from sklearn.metrics import (classification_report, ConfusionMatrixDisplay, log_loss,
                             f1_score, accuracy_score, precision_score, recall_score)

# %%
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
class CFG:
    local = True  # False for kaggle , True for local test
    DeepEval = False#True  # True must enable "Internet on" 
    SEED = 42


     # LLM Config 
    reportTo ="none"
    topK = 40
    topP = 1.0
    temperature = 0.1 #0.5
    repetition_penalty = 1.05 # 1.1
    maxOutToken = 300 #150#180 #100
    test_size = 0.01 #0.005 #0.005 #0.1 #0.01 #0.005 #0.01
    

    # Fine tuning Config
    maxLength = 256 #368 #512 #1024 
    reportTo = "none"
    maxEpoch = 0.005 #0.01 #0.005 #0.5 #0.05 #0.02 #0.05  #0.1 #0.5 #1 #2
    evalSteps = 20 #50 #30 #40 #20 
    learning_rate = 5e-5 #2e-5 #2e-4 #1e-4
    per_device_train_batch_size = 8 #10#6#16 #6 #2 #8#6 #8
    per_device_eval_batch_size =  8 #10 #6#16 #6 #2 #8#6 #8  
    # Lora config
    DROPOUT = 0.05

    warmup_steps= 10 #5# 10
    gradient_accumulation_steps = 8 # 4 #2  #10
    maxTrainStep =  500 #120 #160 #100 #50#100 #250 #150 
    valDatasetSize = 50 #20 #10 #50 #500 # set validiation data size

    #model
    model1 = "/kaggle/input/qwen-3/transformers/8b/1"
    model2 = "/kaggle/input/qwen-3-reranker/transformers/4b/1"
    

    #
    frac = 0.5 #0.3 #0.3 #0.3 #0.1 # Random resample data(reduce train data size )
    

    trainFile = "/kaggle/input/map-charting-student-math-misunderstandings/train.csv"
    testFile  = "/kaggle/input/map-charting-student-math-misunderstandings/test.csv"
    sampleFile = "/kaggle/input/map-charting-student-math-misunderstandings/sample_submission.csv"
    deepspeedConfigFile = "/kaggle/input/deepspeed-config-for-kaggle-t4x2-gpu/deepspeed_config.json"

    #local file
    if local:
        model1 = "unsloth/Qwen3-4B-Instruct-2507"
        model2 = "unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bi"

        trainFile = "dataset/train.csv"
        testFile = "dataset/test.csv"
        sampleFile = "dataset/sample_submission.csv"

# %%
import transformers
transformers.__version__
# Out:
# '4.53.2'

# %%
import trl 
trl.__version__
# Out:
# '0.19.1'

# %%
import unsloth
unsloth.__version__
# Out:
# '2025.7.11'

# %%
import datasets
datasets.__version__
# Out:
# '3.6.0'

# %%
import torch
torch.__version__
# Out:
# '2.7.0+cu126'

# %%
import vllm
vllm.__version__
# Out:
# '0.9.2'

# %%
import huggingface_hub
huggingface_hub.__version__
# Out:
# '0.34.4'

# %%
from unsloth.chat_templates import CHAT_TEMPLATES
print(list(CHAT_TEMPLATES.keys()))
# Out:
# ['unsloth', 'zephyr', 'chatml', 'mistral', 'llama', 'vicuna', 'vicuna_old', 'vicuna old', 'alpaca', 'gemma', 'gemma_chatml', 'gemma2', 'gemma2_chatml', 'llama-3', 'llama3', 'phi-3', 'phi-35', 'phi-3.5', 'llama-3.1', 'llama-31', 'llama-3.2', 'llama-3.3', 'llama-32', 'llama-33', 'qwen-2.5', 'qwen-25', 'qwen25', 'qwen2.5', 'phi-4', 'gemma-3', 'gemma3', 'qwen-3', 'qwen3', 'gemma-3n', 'gemma3n']

# %%
CFG.trainFile
# Out:
# 'dataset/train.csv'

# %%
CFG.model1
# Out:
# 'unsloth/Qwen3-4B-Instruct-2507'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
torch.cuda.is_bf16_supported()
# Out:
# True

# %%
def clearMemory():
    for _ in range(5):
        torch.cuda.empty_cache()
        gc.collect()
        time.sleep(0.3)

# %%
clearMemory()

# %%
def  gpuMemory():
    gpu_stats = torch.cuda.get_device_properties(0)
    start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
    max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
    print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
    print(f"{start_gpu_memory} GB of memory reserved.")
    return start_gpu_memory

# %%
start_gpu_memory =gpuMemory()
# Out:
# GPU = NVIDIA GeForce RTX 3080. Max memory = 11.636 GB.
# 0.0 GB of memory reserved.

# %%
def loraTrainGPUMemory(trainer_stats):
     # @title Show final memory and time stats
    used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
    used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
    used_percentage = round(used_memory / max_memory * 100, 3)
    lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
    print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
    print(
        f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
    )
    print(f"Peak reserved memory = {used_memory} GB.")
    print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
    print(f"Peak reserved memory % of max memory = {used_percentage} %.")
    print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %%
# loraGPUMemory

# %%
# !accelerate config

# %% [markdown]
# ## LLM Initial

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-4B-Instruct-2507",
    max_seq_length = 512, #2048, # Choose any for long context!
    load_in_4bit = False,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# ==((====))==  Unsloth 2025.7.11: Fast Qwen3 patching. Transformers: 4.53.2. vLLM: 0.9.2.
#    \\   /|    NVIDIA GeForce RTX 3080. Num GPUs = 1. Max memory: 11.636 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 8.6. CUDA Toolkit: 12.6. Triton: 3.3.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu and disk.

# %% [markdown]
# ## LoRA Config

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, #32, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 42, #3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.7.11 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen3ForCausalLM(
#       (model): Qwen3Model(
#         (embed_tokens): Embedding(151936, 2560, padding_idx=151654)
#         (layers): ModuleList(
#           (0-35): 36 x Qwen3DecoderLayer(
#             (self_attn): Qwen3Attention(
#               (q_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear(
#                 (base_layer): Linear(in_features=4096, out_features=2560, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2560, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#               (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): Qwen3MLP(
#               (gate_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=9728, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=9728, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=9728, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=9728, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=9728, out_features=2560, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=9728, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2560, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#             (post_attention_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#           )
#         )
#         (norm): Qwen3RMSNorm((2560,), eps=1e-06)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=2560, out_features=151936, bias=False)
#     )
#   )
# )

# %%
print("trainable parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# trainable parameters: 33030144

# %%
trainDF = pd.read_csv(CFG.trainFile)
trainDF.head()
# Out:
#    row_id  QuestionId                                       QuestionText  \
# 0       0       31772  What fraction of the shape is not shaded? Give...
# 1       1       31772  What fraction of the shape is not shaded? Give...
# 2       2       31772  What fraction of the shape is not shaded? Give...
# 3       3       31772  What fraction of the shape is not shaded? Give...
# 4       4       31772  What fraction of the shape is not shaded? Give...
#
#            MC_Answer                                 StudentExplanation  \
# 0  \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1  \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2  \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
# 3  \( \frac{1}{3} \)        1 goes into everything and 3 goes into nine
# 4  \( \frac{1}{3} \)                    1 out of every 3 isn't coloured
#
#        Category Misconception
# 0  True_Correct           NaN
# 1  True_Correct           NaN
# 2  True_Neither           NaN
# 3  True_Neither           NaN
# 4  True_Correct           NaN

# %%
trainDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36696 entries, 0 to 36695
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   row_id              36696 non-null  int64
#  1   QuestionId          36696 non-null  int64
#  2   QuestionText        36696 non-null  object
#  3   MC_Answer           36696 non-null  object
#  4   StudentExplanation  36696 non-null  object
#  5   Category            36696 non-null  object
#  6   Misconception       9860 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 2.0+ MB

# %%
trainDF.describe()
# Out:
#              row_id     QuestionId
# count  36696.000000   36696.000000
# mean   18347.500000   46356.825104
# std    10593.367076   25617.723392
# min        0.000000   31772.000000
# 25%     9173.750000   31777.000000
# 50%    18347.500000   32833.000000
# 75%    27521.250000   33474.000000
# max    36695.000000  109465.000000

# %%
testDF = pd.read_csv(CFG.testFile)
testDF
# Out:
#    row_id  QuestionId                                       QuestionText  \
# 0   36696       31772  What fraction of the shape is not shaded? Give...
# 1   36697       31772  What fraction of the shape is not shaded? Give...
# 2   36698       32835                      Which number is the greatest?
#
#            MC_Answer                                 StudentExplanation
# 0  \( \frac{1}{3} \)  I think that 1/3 is the answer, as it's the si...
# 1  \( \frac{3}{6} \)  i think this answer is because 3 triangles are...
# 2          \( 6.2 \)     because the 2 makes it higher than the others.

# %%
testDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   row_id              3 non-null      int64
#  1   QuestionId          3 non-null      int64
#  2   QuestionText        3 non-null      object
#  3   MC_Answer           3 non-null      object
#  4   StudentExplanation  3 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 252.0+ bytes

# %%
testDF.isnull().sum()
# Out:
# row_id                0
# QuestionId            0
# QuestionText          0
# MC_Answer             0
# StudentExplanation    0
# dtype: int64

# %%
# Nan and Null check
trainDF.isnull().sum()
# Out:
# row_id                    0
# QuestionId                0
# QuestionText              0
# MC_Answer                 0
# StudentExplanation        0
# Category                  0
# Misconception         26836
# dtype: int64

# %%
sample = pd.read_csv(CFG.sampleFile)
sample
# Out:
#    row_id                             Category:Misconception
# 0   36696  True_Correct:NA False_Neither:NA False_Misconc...
# 1   36697  True_Correct:NA False_Neither:NA False_Misconc...
# 2   36698  True_Correct:NA False_Neither:NA False_Misconc...

# %%
sample.columns
# Out:
# Index(['row_id', 'Category:Misconception'], dtype='object')

# %% [markdown]
# ## EDA
# ### Print Columns Values

# %%
def printAllcolumnsValue(df, showAll=True):
    """
    Print DataFrame columns values
    """
    # loop column
    for col in df.columns:
        if showAll is True:
            print(f"{col} : {df[col].unique()}") # print unique value
        else: # only print caterogy column
            if df[col].dtype == "object":
                print(f"{col} : {df[col].unique()}") # print unique value

def printSerieUnquieValue(df):
    """
    print data serie value
    """
    print(f" {df.unique()}")

# %%
printAllcolumnsValue(trainDF, showAll=True)
# Out:
# row_id : [    0     1     2 ... 36693 36694 36695]
# QuestionId : [ 31772  31774  31777  31778  32829  32833  32835  33471  33472  33474
#   76870  89443  91695 104665 109465]
# QuestionText : ['What fraction of the shape is not shaded? Give your answer in its simplest form. [Image: A triangle split into 9 equal smaller triangles. 6 of them are shaded.]'
#  'Calculate \\( \\frac{1}{2} \\div 6 \\)'
#  'A box contains \\( 120 \\) counters. The counters are red or blue. \\( \\frac{3}{5} \\) of the counters are red.\nHow many red counters are there?'
#  '\\( \\frac{A}{10}=\\frac{9}{15} \\) What is the value of \\( A \\) ?'
#  '\\( 2 y=24 \\) What is the value of \\( y \\) ?'
#  'Calculate \\( \\frac{2}{3} \\times 5 \\)'
#  'Which number is the greatest?'
#  'A bag contains \\( 24 \\) yellow and green balls. \\( \\frac{3}{8} \\) of the balls are yellow. How many of the balls are green?'
#  '\\( \\frac{1}{3}+\\frac{2}{5}= \\)'
#  'Sally has \\( \\frac{2}{3} \\) of a whole cake in the fridge. Robert eats \\( \\frac{1}{3} \\) of this piece. What fraction of the whole cake has Robert eaten?\nChoose the number sentence that would solve the word problem.'
#  'This is part of a regular polygon. How many sides does it have? [Image: A diagram showing an obtuse angle labelled 144 degrees]'
#  'What number belongs in the box?\n\\(\n(-8)-(-5)=\n\\square\\)'
#  'Dots have been arranged in these patterns: [Image: Pattern 1 consists of 6 dots, Pattern 2 consists of 10 dots, Pattern 3 consists of 14 dots and Pattern 4 consists of 18 dots] How many dots would there be in Pattern \\( 6 \\) ?'
#  'It takes \\( 3 \\) people a total of \\( 192 \\) hours to build a wall.\n\nHow long would it take if \\( 12 \\) people built the same wall?'
#  'The probability of an event occurring is \\( 0.9 \\).\n\nWhich of the following most accurately describes the likelihood of the event occurring?']
# MC_Answer : ['\\( \\frac{1}{3} \\)' '\\( \\frac{3}{6} \\)' '\\( \\frac{3}{8} \\)'
#  '\\( \\frac{3}{9} \\)' '\\( 3 \\)' '\\( \\frac{1}{12} \\)'
#  '\\( \\frac{6}{2} \\)' '\\( 24 \\)' '\\( 48 \\)' '\\( 60 \\)'
#  '\\( 72 \\)' '\\( 4 \\)' '\\( 6 \\)' '\\( 9 \\)' '\\( 12 \\)'
#  '\\( 22 \\)' '\\( 3 \\frac{1}{3} \\)' '\\( 5 \\frac{2}{3} \\)'
#  '\\( \\frac{10}{15} \\)' '\\( \\frac{2}{15} \\)' '\\( 6.0001 \\)'
#  '\\( 6.079 \\)' '\\( 6.2 \\)' '\\( 15 \\)' '\\( 8 \\)'
#  '\\( \\frac{11}{15} \\)' '\\( \\frac{11}{30} \\)' '\\( \\frac{3}{15} \\)'
#  '\\( \\frac{1}{3} \\times \\frac{2}{3} \\)'
#  '\\( \\frac{1}{3}+\\frac{2}{3} \\)'
#  '\\( \\frac{2}{3} \\div \\frac{1}{3} \\)'
#  '\\( \\frac{2}{3}-\\frac{1}{3} \\)' 'Not enough information' '\\( 10 \\)'
#  '\\( 5 \\)' '\\( -13 \\)' '\\( -3 \\)' '\\( 13 \\)' '\\( 20 \\)'
#  '\\( 26 \\)' '\\( 36 \\)' '\\( 192 \\) hours' '\\( 48 \\) hours'
#  '\\( 64 \\) hours' '\\( 768 \\) hours' 'Certain' 'Impossible' 'Likely'
#  'Unlikely']
# StudentExplanation : ['0ne third is equal to tree nineth'
#  '1 / 3 because 6 over 9 is 2 thirds and 1 third is not shaded.'
#  '1 3rd is half of 3 6th, so it is simplee to understand.' ...
#  'yeah pretty unlikelyy from what it seems.'
#  'you have 9 other numbers to get.'
#  'you have a chanve but it is not i think this because there is 0.9 odds so you have chance chance,']
# Category : ['True_Correct' 'True_Neither' 'True_Misconception' 'False_Neither'
#  'False_Misconception' 'False_Correct']
# Misconception : [nan 'Incomplete' 'WNB' 'SwapDividend' 'Mult' 'FlipChange' 'Irrelevant'
#  'Wrong_Fraction' 'Additive' 'Not_variable' 'Adding_terms'
#  'Inverse_operation' 'Inversion' 'Duplication' 'Wrong_Operation'
#  'Whole_numbers_larger' 'Longer_is_bigger' 'Ignores_zeroes'
#  'Shorter_is_bigger' 'Wrong_fraction' 'Adding_across'
#  'Denominator-only_change' 'Incorrect_equivalent_fraction_addition'
#  'Division' 'Subtraction' 'Unknowable' 'Definition' 'Interior' 'Positive'
#  'Tacking' 'Wrong_term' 'Firstterm' 'Base_rate' 'Multiplying_by_4'
#  'Certainty' 'Scale']

# %%
featureCols = trainDF.columns.tolist()
featureCols
# Out:
# ['row_id',
#  'QuestionId',
#  'QuestionText',
#  'MC_Answer',
#  'StudentExplanation',
#  'Category',
#  'Misconception']

# %%
# clean data
trainDF["Misconception"]= trainDF["Misconception"].fillna("NA") # fill NaN to NA
trainDF["Misconception"].isnull().sum() # check Null
# Out:
# np.int64(0)

# %% [markdown]
# #### combine into target columns

# %%
trainDF['target'] = trainDF["Category"]+":"+trainDF["Misconception"]
trainDF
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 0           0       31772  What fraction of the shape is not shaded? Give...
# 1           1       31772  What fraction of the shape is not shaded? Give...
# 2           2       31772  What fraction of the shape is not shaded? Give...
# 3           3       31772  What fraction of the shape is not shaded? Give...
# 4           4       31772  What fraction of the shape is not shaded? Give...
# ...       ...         ...                                                ...
# 36691   36691      109465  The probability of an event occurring is \( 0....
# 36692   36692      109465  The probability of an event occurring is \( 0....
# 36693   36693      109465  The probability of an event occurring is \( 0....
# 36694   36694      109465  The probability of an event occurring is \( 0....
# 36695   36695      109465  The probability of an event occurring is \( 0....
#
#                MC_Answer                                 StudentExplanation  \
# 0      \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1      \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2      \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
# 3      \( \frac{1}{3} \)        1 goes into everything and 3 goes into nine
# 4      \( \frac{1}{3} \)                    1 out of every 3 isn't coloured
# ...                  ...                                                ...
# 36691           Unlikely                                     very unlikely.
# 36692           Unlikely       yea pretty much unlikely from what it seems.
# 36693           Unlikely          yeah pretty unlikelyy from what it seems.
# 36694           Unlikely                   you have 9 other numbers to get.
# 36695           Unlikely  you have a chanve but it is not i think this b...
#
#             Category Misconception            target
# 0       True_Correct            NA   True_Correct:NA
# 1       True_Correct            NA   True_Correct:NA
# 2       True_Neither            NA   True_Neither:NA
# 3       True_Neither            NA   True_Neither:NA
# 4       True_Correct            NA   True_Correct:NA
# ...              ...           ...               ...
# 36691  False_Neither            NA  False_Neither:NA
# 36692  False_Neither            NA  False_Neither:NA
# 36693  False_Neither            NA  False_Neither:NA
# 36694  False_Neither            NA  False_Neither:NA
# 36695  False_Neither            NA  False_Neither:NA
#
# [36696 rows x 8 columns]

# %% [markdown]
# ### Create Label

# %%
le = LabelEncoder()
trainDF["label"]= le.fit_transform(trainDF['target']) # encode caterogy into label

# %%
trainDF
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 0           0       31772  What fraction of the shape is not shaded? Give...
# 1           1       31772  What fraction of the shape is not shaded? Give...
# 2           2       31772  What fraction of the shape is not shaded? Give...
# 3           3       31772  What fraction of the shape is not shaded? Give...
# 4           4       31772  What fraction of the shape is not shaded? Give...
# ...       ...         ...                                                ...
# 36691   36691      109465  The probability of an event occurring is \( 0....
# 36692   36692      109465  The probability of an event occurring is \( 0....
# 36693   36693      109465  The probability of an event occurring is \( 0....
# 36694   36694      109465  The probability of an event occurring is \( 0....
# 36695   36695      109465  The probability of an event occurring is \( 0....
#
#                MC_Answer                                 StudentExplanation  \
# 0      \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1      \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2      \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
# 3      \( \frac{1}{3} \)        1 goes into everything and 3 goes into nine
# 4      \( \frac{1}{3} \)                    1 out of every 3 isn't coloured
# ...                  ...                                                ...
# 36691           Unlikely                                     very unlikely.
# 36692           Unlikely       yea pretty much unlikely from what it seems.
# 36693           Unlikely          yeah pretty unlikelyy from what it seems.
# 36694           Unlikely                   you have 9 other numbers to get.
# 36695           Unlikely  you have a chanve but it is not i think this b...
#
#             Category Misconception            target  label
# 0       True_Correct            NA   True_Correct:NA     37
# 1       True_Correct            NA   True_Correct:NA     37
# 2       True_Neither            NA   True_Neither:NA     64
# 3       True_Neither            NA   True_Neither:NA     64
# 4       True_Correct            NA   True_Correct:NA     37
# ...              ...           ...               ...    ...
# 36691  False_Neither            NA  False_Neither:NA     36
# 36692  False_Neither            NA  False_Neither:NA     36
# 36693  False_Neither            NA  False_Neither:NA     36
# 36694  False_Neither            NA  False_Neither:NA     36
# 36695  False_Neither            NA  False_Neither:NA     36
#
# [36696 rows x 9 columns]

# %%
# print all unique t
printAllcolumnsValue(trainDF, showAll=True)
# Out:
# row_id : [    0     1     2 ... 36693 36694 36695]
# QuestionId : [ 31772  31774  31777  31778  32829  32833  32835  33471  33472  33474
#   76870  89443  91695 104665 109465]
# QuestionText : ['What fraction of the shape is not shaded? Give your answer in its simplest form. [Image: A triangle split into 9 equal smaller triangles. 6 of them are shaded.]'
#  'Calculate \\( \\frac{1}{2} \\div 6 \\)'
#  'A box contains \\( 120 \\) counters. The counters are red or blue. \\( \\frac{3}{5} \\) of the counters are red.\nHow many red counters are there?'
#  '\\( \\frac{A}{10}=\\frac{9}{15} \\) What is the value of \\( A \\) ?'
#  '\\( 2 y=24 \\) What is the value of \\( y \\) ?'
#  'Calculate \\( \\frac{2}{3} \\times 5 \\)'
#  'Which number is the greatest?'
#  'A bag contains \\( 24 \\) yellow and green balls. \\( \\frac{3}{8} \\) of the balls are yellow. How many of the balls are green?'
#  '\\( \\frac{1}{3}+\\frac{2}{5}= \\)'
#  'Sally has \\( \\frac{2}{3} \\) of a whole cake in the fridge. Robert eats \\( \\frac{1}{3} \\) of this piece. What fraction of the whole cake has Robert eaten?\nChoose the number sentence that would solve the word problem.'
#  'This is part of a regular polygon. How many sides does it have? [Image: A diagram showing an obtuse angle labelled 144 degrees]'
#  'What number belongs in the box?\n\\(\n(-8)-(-5)=\n\\square\\)'
#  'Dots have been arranged in these patterns: [Image: Pattern 1 consists of 6 dots, Pattern 2 consists of 10 dots, Pattern 3 consists of 14 dots and Pattern 4 consists of 18 dots] How many dots would there be in Pattern \\( 6 \\) ?'
#  'It takes \\( 3 \\) people a total of \\( 192 \\) hours to build a wall.\n\nHow long would it take if \\( 12 \\) people built the same wall?'
#  'The probability of an event occurring is \\( 0.9 \\).\n\nWhich of the following most accurately describes the likelihood of the event occurring?']
# MC_Answer : ['\\( \\frac{1}{3} \\)' '\\( \\frac{3}{6} \\)' '\\( \\frac{3}{8} \\)'
#  '\\( \\frac{3}{9} \\)' '\\( 3 \\)' '\\( \\frac{1}{12} \\)'
#  '\\( \\frac{6}{2} \\)' '\\( 24 \\)' '\\( 48 \\)' '\\( 60 \\)'
#  '\\( 72 \\)' '\\( 4 \\)' '\\( 6 \\)' '\\( 9 \\)' '\\( 12 \\)'
#  '\\( 22 \\)' '\\( 3 \\frac{1}{3} \\)' '\\( 5 \\frac{2}{3} \\)'
#  '\\( \\frac{10}{15} \\)' '\\( \\frac{2}{15} \\)' '\\( 6.0001 \\)'
#  '\\( 6.079 \\)' '\\( 6.2 \\)' '\\( 15 \\)' '\\( 8 \\)'
#  '\\( \\frac{11}{15} \\)' '\\( \\frac{11}{30} \\)' '\\( \\frac{3}{15} \\)'
#  '\\( \\frac{1}{3} \\times \\frac{2}{3} \\)'
#  '\\( \\frac{1}{3}+\\frac{2}{3} \\)'
#  '\\( \\frac{2}{3} \\div \\frac{1}{3} \\)'
#  '\\( \\frac{2}{3}-\\frac{1}{3} \\)' 'Not enough information' '\\( 10 \\)'
#  '\\( 5 \\)' '\\( -13 \\)' '\\( -3 \\)' '\\( 13 \\)' '\\( 20 \\)'
#  '\\( 26 \\)' '\\( 36 \\)' '\\( 192 \\) hours' '\\( 48 \\) hours'
#  '\\( 64 \\) hours' '\\( 768 \\) hours' 'Certain' 'Impossible' 'Likely'
#  'Unlikely']
# StudentExplanation : ['0ne third is equal to tree nineth'
#  '1 / 3 because 6 over 9 is 2 thirds and 1 third is not shaded.'
#  '1 3rd is half of 3 6th, so it is simplee to understand.' ...
#  'yeah pretty unlikelyy from what it seems.'
#  'you have 9 other numbers to get.'
#  'you have a chanve but it is not i think this because there is 0.9 odds so you have chance chance,']
# Category : ['True_Correct' 'True_Neither' 'True_Misconception' 'False_Neither'
#  'False_Misconception' 'False_Correct']
# Misconception : ['NA' 'Incomplete' 'WNB' 'SwapDividend' 'Mult' 'FlipChange' 'Irrelevant'
#  'Wrong_Fraction' 'Additive' 'Not_variable' 'Adding_terms'
#  'Inverse_operation' 'Inversion' 'Duplication' 'Wrong_Operation'
#  'Whole_numbers_larger' 'Longer_is_bigger' 'Ignores_zeroes'
#  'Shorter_is_bigger' 'Wrong_fraction' 'Adding_across'
#  'Denominator-only_change' 'Incorrect_equivalent_fraction_addition'
#  'Division' 'Subtraction' 'Unknowable' 'Definition' 'Interior' 'Positive'
#  'Tacking' 'Wrong_term' 'Firstterm' 'Base_rate' 'Multiplying_by_4'
#  'Certainty' 'Scale']
# target : ['True_Correct:NA' 'True_Neither:NA' 'True_Misconception:Incomplete'
#  'True_Misconception:WNB' 'False_Neither:NA' 'False_Misconception:WNB'
#  'False_Misconception:Incomplete' 'False_Correct:NA'
#  'False_Misconception:SwapDividend' 'False_Misconception:Mult'
#  'False_Misconception:FlipChange' 'True_Misconception:SwapDividend'
#  'True_Misconception:Mult' 'True_Misconception:FlipChange'
#  'False_Misconception:Irrelevant' 'False_Misconception:Wrong_Fraction'
#  'False_Misconception:Additive' 'True_Misconception:Irrelevant'
#  'True_Misconception:Additive' 'True_Misconception:Not_variable'
#  'False_Misconception:Adding_terms' 'False_Misconception:Not_variable'
#  'False_Misconception:Inverse_operation' 'True_Misconception:Inversion'
#  'True_Misconception:Duplication' 'False_Misconception:Duplication'
#  'False_Misconception:Inversion' 'False_Misconception:Wrong_Operation'
#  'False_Misconception:Whole_numbers_larger'
#  'False_Misconception:Longer_is_bigger'
#  'False_Misconception:Ignores_zeroes'
#  'False_Misconception:Shorter_is_bigger'
#  'True_Misconception:Whole_numbers_larger'
#  'True_Misconception:Shorter_is_bigger'
#  'True_Misconception:Longer_is_bigger' 'True_Misconception:Wrong_fraction'
#  'False_Misconception:Wrong_fraction' 'True_Misconception:Adding_across'
#  'True_Misconception:Denominator-only_change'
#  'True_Misconception:Incorrect_equivalent_fraction_addition'
#  'False_Misconception:Denominator-only_change'
#  'False_Misconception:Incorrect_equivalent_fraction_addition'
#  'False_Misconception:Adding_across' 'True_Misconception:Division'
#  'True_Misconception:Subtraction' 'False_Misconception:Subtraction'
#  'False_Misconception:Division' 'False_Misconception:Unknowable'
#  'False_Misconception:Definition' 'False_Misconception:Interior'
#  'True_Misconception:Definition' 'False_Misconception:Positive'
#  'False_Misconception:Tacking' 'True_Misconception:Tacking'
#  'True_Misconception:Positive' 'False_Misconception:Wrong_term'
#  'False_Misconception:Firstterm' 'True_Misconception:Wrong_term'
#  'True_Misconception:Firstterm' 'False_Misconception:Base_rate'
#  'True_Misconception:Base_rate' 'True_Misconception:Multiplying_by_4'
#  'False_Misconception:Multiplying_by_4' 'False_Misconception:Certainty'
#  'False_Misconception:Scale']
# label : [37 64 47 60 36 30 13  0 27 20 11 58 52 46 18 32  3 50 39 54  2 22 16 49
#  44  9 17 33 31 19 12 25 61 56 51 62 34 38 42 48  7 14  1 43 57 26  8 29
#   6 15 41 23 28 59 55 35 10 63 45  4 40 53 21  5 24]

# %% [markdown]
# ### Get Label Catergory class name

# %%
targetClasses = le.classes_   
targetClasses
# Out:
# array(['False_Correct:NA', 'False_Misconception:Adding_across',
#        'False_Misconception:Adding_terms', 'False_Misconception:Additive',
#        'False_Misconception:Base_rate', 'False_Misconception:Certainty',
#        'False_Misconception:Definition',
#        'False_Misconception:Denominator-only_change',
#        'False_Misconception:Division', 'False_Misconception:Duplication',
#        'False_Misconception:Firstterm', 'False_Misconception:FlipChange',
#        'False_Misconception:Ignores_zeroes',
#        'False_Misconception:Incomplete',
#        'False_Misconception:Incorrect_equivalent_fraction_addition',
#        'False_Misconception:Interior',
#        'False_Misconception:Inverse_operation',
#        'False_Misconception:Inversion', 'False_Misconception:Irrelevant',
#        'False_Misconception:Longer_is_bigger', 'False_Misconception:Mult',
#        'False_Misconception:Multiplying_by_4',
#        'False_Misconception:Not_variable', 'False_Misconception:Positive',
#        'False_Misconception:Scale',
#        'False_Misconception:Shorter_is_bigger',
#        'False_Misconception:Subtraction',
#        'False_Misconception:SwapDividend', 'False_Misconception:Tacking',
#        'False_Misconception:Unknowable', 'False_Misconception:WNB',
#        'False_Misconception:Whole_numbers_larger',
#        'False_Misconception:Wrong_Fraction',
#        'False_Misconception:Wrong_Operation',
#        'False_Misconception:Wrong_fraction',
#        'False_Misconception:Wrong_term', 'False_Neither:NA',
#        'True_Correct:NA', 'True_Misconception:Adding_across',
#        'True_Misconception:Additive', 'True_Misconception:Base_rate',
#        'True_Misconception:Definition',
#        'True_Misconception:Denominator-only_change',
#        'True_Misconception:Division', 'True_Misconception:Duplication',
#        'True_Misconception:Firstterm', 'True_Misconception:FlipChange',
#        'True_Misconception:Incomplete',
#        'True_Misconception:Incorrect_equivalent_fraction_addition',
#        'True_Misconception:Inversion', 'True_Misconception:Irrelevant',
#        'True_Misconception:Longer_is_bigger', 'True_Misconception:Mult',
#        'True_Misconception:Multiplying_by_4',
#        'True_Misconception:Not_variable', 'True_Misconception:Positive',
#        'True_Misconception:Shorter_is_bigger',
#        'True_Misconception:Subtraction',
#        'True_Misconception:SwapDividend', 'True_Misconception:Tacking',
#        'True_Misconception:WNB',
#        'True_Misconception:Whole_numbers_larger',
#        'True_Misconception:Wrong_fraction',
#        'True_Misconception:Wrong_term', 'True_Neither:NA'], dtype=object)

# %%
nClasses = len(targetClasses)
nClasses
# Out:
# 65

# %%
print(f"Train shape: {trainDF.shape} with {nClasses} target classes")
trainDF.head()
# Out:
# Train shape: (36696, 9) with 65 target classes
#    row_id  QuestionId                                       QuestionText  \
# 0       0       31772  What fraction of the shape is not shaded? Give...
# 1       1       31772  What fraction of the shape is not shaded? Give...
# 2       2       31772  What fraction of the shape is not shaded? Give...
# 3       3       31772  What fraction of the shape is not shaded? Give...
# 4       4       31772  What fraction of the shape is not shaded? Give...
#
#            MC_Answer                                 StudentExplanation  \
# 0  \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1  \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2  \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
# 3  \( \frac{1}{3} \)        1 goes into everything and 3 goes into nine
# 4  \( \frac{1}{3} \)                    1 out of every 3 isn't coloured
#
#        Category Misconception           target  label
# 0  True_Correct            NA  True_Correct:NA     37
# 1  True_Correct            NA  True_Correct:NA     37
# 2  True_Neither            NA  True_Neither:NA     64
# 3  True_Neither            NA  True_Neither:NA     64
# 4  True_Correct            NA  True_Correct:NA     37

# %% [markdown]
# # Feature Engineering
#
# ### Add correct answer flag

# %%
idx = trainDF.apply(lambda row: row["Category"].split("_")[0] , axis=1) == "True" # get Category with True 
idx
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 36691    False
# 36692    False
# 36693    False
# 36694    False
# 36695    False
# Length: 36696, dtype: bool

# %%
correct = trainDF.loc[idx].copy()
correct
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 0           0       31772  What fraction of the shape is not shaded? Give...
# 1           1       31772  What fraction of the shape is not shaded? Give...
# 2           2       31772  What fraction of the shape is not shaded? Give...
# 3           3       31772  What fraction of the shape is not shaded? Give...
# 4           4       31772  What fraction of the shape is not shaded? Give...
# ...       ...         ...                                                ...
# 36275   36275      109465  The probability of an event occurring is \( 0....
# 36276   36276      109465  The probability of an event occurring is \( 0....
# 36277   36277      109465  The probability of an event occurring is \( 0....
# 36278   36278      109465  The probability of an event occurring is \( 0....
# 36279   36279      109465  The probability of an event occurring is \( 0....
#
#                MC_Answer                                 StudentExplanation  \
# 0      \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1      \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2      \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
# 3      \( \frac{1}{3} \)        1 goes into everything and 3 goes into nine
# 4      \( \frac{1}{3} \)                    1 out of every 3 isn't coloured
# ...                  ...                                                ...
# 36275             Likely  very close to one but not one so it cant be ce...
# 36276             Likely     very high probability however it's not certain
# 36277             Likely  we should use likely because we dont know for ...
# 36278             Likely  well 0.9 = 90% and the only way something can ...
# 36279             Likely  well normally if it is in the decimals its the...
#
#            Category Misconception           target  label
# 0      True_Correct            NA  True_Correct:NA     37
# 1      True_Correct            NA  True_Correct:NA     37
# 2      True_Neither            NA  True_Neither:NA     64
# 3      True_Neither            NA  True_Neither:NA     64
# 4      True_Correct            NA  True_Correct:NA     37
# ...             ...           ...              ...    ...
# 36275  True_Correct            NA  True_Correct:NA     37
# 36276  True_Neither            NA  True_Neither:NA     64
# 36277  True_Neither            NA  True_Neither:NA     64
# 36278  True_Correct            NA  True_Correct:NA     37
# 36279  True_Correct            NA  True_Correct:NA     37
#
# [20470 rows x 9 columns]

# %%
# group MC anwser with count 
correct['c'] = correct.groupby(['QuestionId','MC_Answer']).MC_Answer.transform('count')
correct = correct.sort_values('c',ascending=False) # sort value 
correct
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 15         15       31772  What fraction of the shape is not shaded? Give...
# 14         14       31772  What fraction of the shape is not shaded? Give...
# 13         13       31772  What fraction of the shape is not shaded? Give...
# 12         12       31772  What fraction of the shape is not shaded? Give...
# 11         11       31772  What fraction of the shape is not shaded? Give...
# ...       ...         ...                                                ...
# 14335   14335       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 14321   14321       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 14305   14305       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 14280   14280       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 14418   14418       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
#
#                MC_Answer                                 StudentExplanation  \
# 15     \( \frac{1}{3} \)  1/3 is equal to 3 because if 3 are not shared ...
# 14     \( \frac{1}{3} \)  1/3 is equal to 3 because if 3 are not shared ...
# 13     \( \frac{1}{3} \)              1/3 is also 1/3 in its simplest form.
# 12     \( \frac{1}{3} \)                 1/3 is a simplafide version of 3/9
# 11     \( \frac{1}{3} \)  1/3 because there are threee triangles that ar...
# ...                  ...                                                ...
# 14335            \( 9 \)  Il believe that is the ansewer because I calcu...
# 14321            \( 9 \)   I think it's C because 6/10 is the same as 9/15.
# 14305            \( 9 \)  I divided 9/15 by 3, then got 3/5 and timsed i...
# 14280            \( 9 \)             Because 10 is 2 / 3 of 15, and 2 is 6.
# 14418            \( 9 \)  this is because the top numbers go up in three...
#
#                  Category Misconception                         target  label  \
# 15           True_Neither            NA                True_Neither:NA     64
# 14           True_Neither            NA                True_Neither:NA     64
# 13           True_Neither            NA                True_Neither:NA     64
# 12           True_Correct            NA                True_Correct:NA     37
# 11           True_Correct            NA                True_Correct:NA     37
# ...                   ...           ...                            ...    ...
# 14335        True_Neither            NA                True_Neither:NA     64
# 14321        True_Correct            NA                True_Correct:NA     37
# 14305        True_Correct            NA                True_Correct:NA     37
# 14280        True_Neither            NA                True_Neither:NA     64
# 14418  True_Misconception    Irrelevant  True_Misconception:Irrelevant     50
#
#           c
# 15     2348
# 14     2348
# 13     2348
# 12     2348
# 11     2348
# ...     ...
# 14335    12
# 14321    12
# 14305    12
# 14280    12
# 14418    12
#
# [20470 rows x 10 columns]

# %%
# Drop duplicateds ID
correct = correct.drop_duplicates(['QuestionId']) #drop dprlicate id
correct = correct[['QuestionId','MC_Answer']]
correct
# Out:
#        QuestionId                             MC_Answer
# 15          31772                     \( \frac{1}{3} \)
# 7424        31774                    \( \frac{1}{12} \)
# 10749       31777                              \( 72 \)
# 12544       31778                               \( 6 \)
# 16136       32829                              \( 12 \)
# 21998       32835                             \( 6.2 \)
# 24284       33472                   \( \frac{11}{15} \)
# 18173       32833                   \( 3 \frac{1}{3} \)
# 33182       91695                              \( 26 \)
# 31003       89443                              \( -3 \)
# 22578       33471                              \( 15 \)
# 26983       33474  \( \frac{1}{3} \times \frac{2}{3} \)
# 36279      109465                                Likely
# 28526       76870                              \( 10 \)
# 34999      104665                        \( 48 \) hours

# %%
# set correct flag = 1
correct["is_correct"] = 1
correct
# Out:
#        QuestionId                             MC_Answer  is_correct
# 15          31772                     \( \frac{1}{3} \)           1
# 7424        31774                    \( \frac{1}{12} \)           1
# 10749       31777                              \( 72 \)           1
# 12544       31778                               \( 6 \)           1
# 16136       32829                              \( 12 \)           1
# 21998       32835                             \( 6.2 \)           1
# 24284       33472                   \( \frac{11}{15} \)           1
# 18173       32833                   \( 3 \frac{1}{3} \)           1
# 33182       91695                              \( 26 \)           1
# 31003       89443                              \( -3 \)           1
# 22578       33471                              \( 15 \)           1
# 26983       33474  \( \frac{1}{3} \times \frac{2}{3} \)           1
# 36279      109465                                Likely           1
# 28526       76870                              \( 10 \)           1
# 34999      104665                        \( 48 \) hours           1

# %% [markdown]
# ### Merge training data

# %%
trainDF = trainDF.merge(correct, on=['QuestionId','MC_Answer'], how='left')
trainDF["is_correct"] = trainDF["is_correct"].fillna(0) # fill miss data to 0

# %%
trainDF["is_correct"] = trainDF["is_correct"].astype(int) # change is_correct data type to int

# %%
trainDF
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 0           0       31772  What fraction of the shape is not shaded? Give...
# 1           1       31772  What fraction of the shape is not shaded? Give...
# 2           2       31772  What fraction of the shape is not shaded? Give...
# 3           3       31772  What fraction of the shape is not shaded? Give...
# 4           4       31772  What fraction of the shape is not shaded? Give...
# ...       ...         ...                                                ...
# 36691   36691      109465  The probability of an event occurring is \( 0....
# 36692   36692      109465  The probability of an event occurring is \( 0....
# 36693   36693      109465  The probability of an event occurring is \( 0....
# 36694   36694      109465  The probability of an event occurring is \( 0....
# 36695   36695      109465  The probability of an event occurring is \( 0....
#
#                MC_Answer                                 StudentExplanation  \
# 0      \( \frac{1}{3} \)                  0ne third is equal to tree nineth
# 1      \( \frac{1}{3} \)  1 / 3 because 6 over 9 is 2 thirds and 1 third...
# 2      \( \frac{1}{3} \)  1 3rd is half of 3 6th, so it is simplee to un...
# 3      \( \frac{1}{3} \)        1 goes into everything and 3 goes into nine
# 4      \( \frac{1}{3} \)                    1 out of every 3 isn't coloured
# ...                  ...                                                ...
# 36691           Unlikely                                     very unlikely.
# 36692           Unlikely       yea pretty much unlikely from what it seems.
# 36693           Unlikely          yeah pretty unlikelyy from what it seems.
# 36694           Unlikely                   you have 9 other numbers to get.
# 36695           Unlikely  you have a chanve but it is not i think this b...
#
#             Category Misconception            target  label  is_correct
# 0       True_Correct            NA   True_Correct:NA     37           1
# 1       True_Correct            NA   True_Correct:NA     37           1
# 2       True_Neither            NA   True_Neither:NA     64           1
# 3       True_Neither            NA   True_Neither:NA     64           1
# 4       True_Correct            NA   True_Correct:NA     37           1
# ...              ...           ...               ...    ...         ...
# 36691  False_Neither            NA  False_Neither:NA     36           0
# 36692  False_Neither            NA  False_Neither:NA     36           0
# 36693  False_Neither            NA  False_Neither:NA     36           0
# 36694  False_Neither            NA  False_Neither:NA     36           0
# 36695  False_Neither            NA  False_Neither:NA     36           0
#
# [36696 rows x 10 columns]

# %%
trainDF["is_correct"].value_counts().plot(kind="bar", title="Correct vs Incorrect");

# %% [markdown]
# ## Seem the training Data extremely imbalance

# %%
trainDF["label"].value_counts().plot(kind="bar", title="Distribution Label");

# %%
trainDF["label"].value_counts().describe()
# Out:
# count       65.000000
# mean       564.553846
# std       2071.725263
# min          1.000000
# 25%          6.000000
# 50%         50.000000
# 75%        291.000000
# max      14802.000000
# Name: count, dtype: float64

# %%
trainDF["label"].value_counts()[:50]  # top 50
# Out:
# label
# 37    14802
# 36     6542
# 64     5265
# 13     1446
# 3       891
# 9       698
# 26      618
# 23      564
# 35      550
# 34      412
# 18      409
# 17      409
# 20      345
# 7       332
# 31      328
# 1       306
# 30      291
# 29      282
# 32      273
# 0       227
# 27      198
# 24      179
# 59      162
# 22      153
# 28      128
# 2        97
# 10       96
# 21       93
# 50       88
# 11       74
# 8        58
# 6        51
# 15       50
# 39       38
# 12       23
# 19       23
# 4        22
# 16       21
# 5        18
# 56       17
# 45       11
# 47        8
# 58        8
# 60        8
# 63        8
# 52        8
# 14        7
# 25        6
# 44        6
# 33        6
# Name: count, dtype: int64

# %% [markdown]
# ## Merge into Test /Submit Data

# %%
testDF = testDF.merge(correct, on=['QuestionId','MC_Answer'], how='left')
testDF["is_correct"] = testDF["is_correct"].fillna(0)  # fill Na to 0

# %%
testDF["is_correct"] = testDF["is_correct"].astype(int)
testDF
# Out:
#    row_id  QuestionId                                       QuestionText  \
# 0   36696       31772  What fraction of the shape is not shaded? Give...
# 1   36697       31772  What fraction of the shape is not shaded? Give...
# 2   36698       32835                      Which number is the greatest?
#
#            MC_Answer                                 StudentExplanation  \
# 0  \( \frac{1}{3} \)  I think that 1/3 is the answer, as it's the si...
# 1  \( \frac{3}{6} \)  i think this answer is because 3 triangles are...
# 2          \( 6.2 \)     because the 2 makes it higher than the others.
#
#    is_correct
# 0           1
# 1           0
# 2           1

# %% [markdown]
# ## Visualize Get Answer choices

# %%
from IPython.display import display, Math, Latex

# %%
temp = trainDF.groupby(["QuestionId", "MC_Answer"]).size().reset_index(name="count")
temp
# Out:
#     QuestionId                             MC_Answer  count
# 0        31772                     \( \frac{1}{3} \)   2348
# 1        31772                     \( \frac{3}{6} \)    412
# 2        31772                     \( \frac{3}{8} \)    118
# 3        31772                     \( \frac{3}{9} \)   1979
# 4        31774                               \( 3 \)    659
# 5        31774                    \( \frac{1}{12} \)   1918
# 6        31774                     \( \frac{1}{3} \)    251
# 7        31774                     \( \frac{6}{2} \)    287
# 8        31777                              \( 24 \)    255
# 9        31777                              \( 48 \)    406
# 10       31777                              \( 60 \)    350
# 11       31777                              \( 72 \)   1798
# 12       31778                               \( 3 \)    627
# 13       31778                               \( 4 \)   1108
# 14       31778                               \( 6 \)   1755
# 15       31778                               \( 9 \)    150
# 16       32829                              \( 12 \)   1716
# 17       32829                              \( 22 \)    148
# 18       32829                               \( 4 \)    248
# 19       32829                              \( 48 \)     44
# 20       32833                   \( 3 \frac{1}{3} \)   1601
# 21       32833                   \( 5 \frac{2}{3} \)     78
# 22       32833                   \( \frac{10}{15} \)    906
# 23       32833                    \( \frac{2}{15} \)    520
# 24       32835                               \( 6 \)    478
# 25       32835                          \( 6.0001 \)     64
# 26       32835                           \( 6.079 \)    116
# 27       32835                             \( 6.2 \)   1674
# 28       33471                              \( 15 \)    874
# 29       33471                               \( 3 \)     40
# 30       33471                               \( 8 \)     56
# 31       33471                               \( 9 \)    572
# 32       33472                   \( \frac{11}{15} \)   1651
# 33       33472                   \( \frac{11}{30} \)    116
# 34       33472                    \( \frac{3}{15} \)    565
# 35       33472                     \( \frac{3}{8} \)    468
# 36       33474  \( \frac{1}{3} \times \frac{2}{3} \)    630
# 37       33474         \( \frac{1}{3}+\frac{2}{3} \)     49
# 38       33474    \( \frac{2}{3} \div \frac{1}{3} \)    147
# 39       33474         \( \frac{2}{3}-\frac{1}{3} \)    940
# 40       76870                Not enough information    403
# 41       76870                              \( 10 \)    508
# 42       76870                               \( 5 \)    140
# 43       76870                               \( 6 \)    135
# 44       89443                             \( -13 \)    798
# 45       89443                              \( -3 \)   1394
# 46       89443                              \( 13 \)    396
# 47       89443                               \( 3 \)    466
# 48       91695                              \( 20 \)    102
# 49       91695                              \( 22 \)    718
# 50       91695                              \( 26 \)   1547
# 51       91695                              \( 36 \)    243
# 52      104665                       \( 192 \) hours      9
# 53      104665                        \( 48 \) hours    497
# 54      104665                        \( 64 \) hours     62
# 55      104665                       \( 768 \) hours    105
# 56      109465                               Certain     64
# 57      109465                            Impossible     18
# 58      109465                                Likely    553
# 59      109465                              Unlikely    416

# %%
# add Ranking
temp["rank"] = temp.groupby("QuestionId")['count'].rank(method='dense', ascending=False).astype(int) - 1
temp
# Out:
#     QuestionId                             MC_Answer  count  rank
# 0        31772                     \( \frac{1}{3} \)   2348     0
# 1        31772                     \( \frac{3}{6} \)    412     2
# 2        31772                     \( \frac{3}{8} \)    118     3
# 3        31772                     \( \frac{3}{9} \)   1979     1
# 4        31774                               \( 3 \)    659     1
# 5        31774                    \( \frac{1}{12} \)   1918     0
# 6        31774                     \( \frac{1}{3} \)    251     3
# 7        31774                     \( \frac{6}{2} \)    287     2
# 8        31777                              \( 24 \)    255     3
# 9        31777                              \( 48 \)    406     1
# 10       31777                              \( 60 \)    350     2
# 11       31777                              \( 72 \)   1798     0
# 12       31778                               \( 3 \)    627     2
# 13       31778                               \( 4 \)   1108     1
# 14       31778                               \( 6 \)   1755     0
# 15       31778                               \( 9 \)    150     3
# 16       32829                              \( 12 \)   1716     0
# 17       32829                              \( 22 \)    148     2
# 18       32829                               \( 4 \)    248     1
# 19       32829                              \( 48 \)     44     3
# 20       32833                   \( 3 \frac{1}{3} \)   1601     0
# 21       32833                   \( 5 \frac{2}{3} \)     78     3
# 22       32833                   \( \frac{10}{15} \)    906     1
# 23       32833                    \( \frac{2}{15} \)    520     2
# 24       32835                               \( 6 \)    478     1
# 25       32835                          \( 6.0001 \)     64     3
# 26       32835                           \( 6.079 \)    116     2
# 27       32835                             \( 6.2 \)   1674     0
# 28       33471                              \( 15 \)    874     0
# 29       33471                               \( 3 \)     40     3
# 30       33471                               \( 8 \)     56     2
# 31       33471                               \( 9 \)    572     1
# 32       33472                   \( \frac{11}{15} \)   1651     0
# 33       33472                   \( \frac{11}{30} \)    116     3
# 34       33472                    \( \frac{3}{15} \)    565     1
# 35       33472                     \( \frac{3}{8} \)    468     2
# 36       33474  \( \frac{1}{3} \times \frac{2}{3} \)    630     1
# 37       33474         \( \frac{1}{3}+\frac{2}{3} \)     49     3
# 38       33474    \( \frac{2}{3} \div \frac{1}{3} \)    147     2
# 39       33474         \( \frac{2}{3}-\frac{1}{3} \)    940     0
# 40       76870                Not enough information    403     1
# 41       76870                              \( 10 \)    508     0
# 42       76870                               \( 5 \)    140     2
# 43       76870                               \( 6 \)    135     3
# 44       89443                             \( -13 \)    798     1
# 45       89443                              \( -3 \)   1394     0
# 46       89443                              \( 13 \)    396     3
# 47       89443                               \( 3 \)    466     2
# 48       91695                              \( 20 \)    102     3
# 49       91695                              \( 22 \)    718     1
# 50       91695                              \( 26 \)   1547     0
# 51       91695                              \( 36 \)    243     2
# 52      104665                       \( 192 \) hours      9     3
# 53      104665                        \( 48 \) hours    497     0
# 54      104665                        \( 64 \) hours     62     2
# 55      104665                       \( 768 \) hours    105     1
# 56      109465                               Certain     64     2
# 57      109465                            Impossible     18     3
# 58      109465                                Likely    553     0
# 59      109465                              Unlikely    416     1

# %%
temp = temp.drop('count',axis=1)
temp = temp.sort_values(['QuestionId','rank'])
temp
# Out:
#     QuestionId                             MC_Answer  rank
# 0        31772                     \( \frac{1}{3} \)     0
# 3        31772                     \( \frac{3}{9} \)     1
# 1        31772                     \( \frac{3}{6} \)     2
# 2        31772                     \( \frac{3}{8} \)     3
# 5        31774                    \( \frac{1}{12} \)     0
# 4        31774                               \( 3 \)     1
# 7        31774                     \( \frac{6}{2} \)     2
# 6        31774                     \( \frac{1}{3} \)     3
# 11       31777                              \( 72 \)     0
# 9        31777                              \( 48 \)     1
# 10       31777                              \( 60 \)     2
# 8        31777                              \( 24 \)     3
# 14       31778                               \( 6 \)     0
# 13       31778                               \( 4 \)     1
# 12       31778                               \( 3 \)     2
# 15       31778                               \( 9 \)     3
# 16       32829                              \( 12 \)     0
# 18       32829                               \( 4 \)     1
# 17       32829                              \( 22 \)     2
# 19       32829                              \( 48 \)     3
# 20       32833                   \( 3 \frac{1}{3} \)     0
# 22       32833                   \( \frac{10}{15} \)     1
# 23       32833                    \( \frac{2}{15} \)     2
# 21       32833                   \( 5 \frac{2}{3} \)     3
# 27       32835                             \( 6.2 \)     0
# 24       32835                               \( 6 \)     1
# 26       32835                           \( 6.079 \)     2
# 25       32835                          \( 6.0001 \)     3
# 28       33471                              \( 15 \)     0
# 31       33471                               \( 9 \)     1
# 30       33471                               \( 8 \)     2
# 29       33471                               \( 3 \)     3
# 32       33472                   \( \frac{11}{15} \)     0
# 34       33472                    \( \frac{3}{15} \)     1
# 35       33472                     \( \frac{3}{8} \)     2
# 33       33472                   \( \frac{11}{30} \)     3
# 39       33474         \( \frac{2}{3}-\frac{1}{3} \)     0
# 36       33474  \( \frac{1}{3} \times \frac{2}{3} \)     1
# 38       33474    \( \frac{2}{3} \div \frac{1}{3} \)     2
# 37       33474         \( \frac{1}{3}+\frac{2}{3} \)     3
# 41       76870                              \( 10 \)     0
# 40       76870                Not enough information     1
# 42       76870                               \( 5 \)     2
# 43       76870                               \( 6 \)     3
# 45       89443                              \( -3 \)     0
# 44       89443                             \( -13 \)     1
# 47       89443                               \( 3 \)     2
# 46       89443                              \( 13 \)     3
# 50       91695                              \( 26 \)     0
# 49       91695                              \( 22 \)     1
# 51       91695                              \( 36 \)     2
# 48       91695                              \( 20 \)     3
# 53      104665                        \( 48 \) hours     0
# 55      104665                       \( 768 \) hours     1
# 54      104665                        \( 64 \) hours     2
# 52      104665                       \( 192 \) hours     3
# 58      109465                                Likely     0
# 59      109465                              Unlikely     1
# 56      109465                               Certain     2
# 57      109465                            Impossible     3

# %%
Qid = temp["QuestionId"].unique() # get unique questionid
for q in Qid:
    question = trainDF.loc[trainDF.QuestionId==q].iloc[0]["QuestionText"] # get Question Text for specific QuestionId
    choices = temp.loc[temp["QuestionId"] ==q]["MC_Answer"].values #
    labels="ABCD" # define labels name
    choiceStr = " ".join([f"({labels[i]}) {choice}" for  i, choice in enumerate(choices)])
    print()
    display(Latex(f"Question Id: {q}: {question}"))
    display(Latex(f"MC Answer: {choiceStr}\n\r"))
    
    # print(f"question: {question}, choices: {choices}  \n\r")
# Out:
# Question Id: 31772: What fraction of the shape is not shaded? Give your answer in its simplest form. [Image: A triangle split into 9 equal smaller triangles. 6 of them are shaded.]
# MC Answer: (A) \( \frac{1}{3} \) (B) \( \frac{3}{9} \) (C) \( \frac{3}{6} \) (D) \( \frac{3}{8} \)
# Question Id: 31774: Calculate \( \frac{1}{2} \div 6 \)
# MC Answer: (A) \( \frac{1}{12} \) (B) \( 3 \) (C) \( \frac{6}{2} \) (D) \( \frac{1}{3} \)
# Question Id: 31777: A box contains \( 120 \) counters. The counters are red or blue. \( \frac{3}{5} \) of the counters are red.
# How many red counters are there?
# MC Answer: (A) \( 72 \) (B) \( 48 \) (C) \( 60 \) (D) \( 24 \)
# Question Id: 31778: \( \frac{A}{10}=\frac{9}{15} \) What is the value of \( A \) ?
# MC Answer: (A) \( 6 \) (B) \( 4 \) (C) \( 3 \) (D) \( 9 \)
# Question Id: 32829: \( 2 y=24 \) What is the value of \( y \) ?
# MC Answer: (A) \( 12 \) (B) \( 4 \) (C) \( 22 \) (D) \( 48 \)
# Question Id: 32833: Calculate \( \frac{2}{3} \times 5 \)
# MC Answer: (A) \( 3 \frac{1}{3} \) (B) \( \frac{10}{15} \) (C) \( \frac{2}{15} \) (D) \( 5 \frac{2}{3} \)
# Question Id: 32835: Which number is the greatest?
# MC Answer: (A) \( 6.2 \) (B) \( 6 \) (C) \( 6.079 \) (D) \( 6.0001 \)
# Question Id: 33471: A bag contains \( 24 \) yellow and green balls. \( \frac{3}{8} \) of the balls are yellow. How many of the balls are green?
# MC Answer: (A) \( 15 \) (B) \( 9 \) (C) \( 8 \) (D) \( 3 \)
# Question Id: 33472: \( \frac{1}{3}+\frac{2}{5}= \)
# MC Answer: (A) \( \frac{11}{15} \) (B) \( \frac{3}{15} \) (C) \( \frac{3}{8} \) (D) \( \frac{11}{30} \)
# Question Id: 33474: Sally has \( \frac{2}{3} \) of a whole cake in the fridge. Robert eats \( \frac{1}{3} \) of this piece. What fraction of the whole cake has Robert eaten?
# Choose the number sentence that would solve the word problem.
# MC Answer: (A) \( \frac{2}{3}-\frac{1}{3} \) (B) \( \frac{1}{3} \times \frac{2}{3} \) (C) \( \frac{2}{3} \div \frac{1}{3} \) (D) \( \frac{1}{3}+\frac{2}{3} \)
# Question Id: 76870: This is part of a regular polygon. How many sides does it have? [Image: A diagram showing an obtuse angle labelled 144 degrees]
# MC Answer: (A) \( 10 \) (B) Not enough information (C) \( 5 \) (D) \( 6 \)
# Question Id: 89443: What number belongs in the box?
# \(
# (-8)-(-5)=
# \square\)
# MC Answer: (A) \( -3 \) (B) \( -13 \) (C) \( 3 \) (D) \( 13 \)
# Question Id: 91695: Dots have been arranged in these patterns: [Image: Pattern 1 consists of 6 dots, Pattern 2 consists of 10 dots, Pattern 3 consists of 14 dots and Pattern 4 consists of 18 dots] How many dots would there be in Pattern \( 6 \) ?
# MC Answer: (A) \( 26 \) (B) \( 22 \) (C) \( 36 \) (D) \( 20 \)
# Question Id: 104665: It takes \( 3 \) people a total of \( 192 \) hours to build a wall.
#
# How long would it take if \( 12 \) people built the same wall?
# MC Answer: (A) \( 48 \) hours (B) \( 768 \) hours (C) \( 64 \) hours (D) \( 192 \) hours
# Question Id: 109465: The probability of an event occurring is \( 0.9 \).
#
# Which of the following most accurately describes the likelihood of the event occurring?
# MC Answer: (A) Likely (B) Unlikely (C) Certain (D) Impossible

# %%
len(Qid)
# Out:
# 15

# %%
clearMemory()

# %% [markdown]
# <!-- ### Undersampling is simple way to reduce impact for training imbalance class -->
# # Imbalance Class Handling
# To address the extreme class imbalance in your training dataset, you can apply sampling techniques to create a more balanced dataset for fine-tuning. Here are common and effective approaches:
#
# ### Undersampling the Majority Classes
# Randomly remove samples from highly frequent classes (e.g., label 37 with 14,802 samples) to reduce their dominance.
#
# Techniques like Near Miss or Tomek Links select majority samples close to minority samples to keep important points and remove redundant ones.
#
# Downsampling ensures batches contain more representative samples of minority classes, helping the model learn minority patterns better.
#
# ### Oversampling the Minority Classes
# Increase the number of samples in minority classes by replicating existing samples or synthetically generating new ones (e.g., SMOTE or Perceptual Borderline SMOTE).
#
# Synthetic oversampling creates new minority samples by interpolating between nearest neighbors, improving representation without losing information.
#
# ### Hybrid Sampling
# Combine undersampling and oversampling to balance the dataset effectively without losing valuable majority class information.
#
# For example, reduce majority class samples moderately and apply synthetic oversampling to minority classes.
#
# Hybrid methods have been shown to perform well in highly imbalanced multi-class settings.
#
# ## Additional Suggestions
# - Class Weights: Alternatively or additionally, assign higher loss weights to minority classes during training to force the model to pay more attention to them without changing the dataset distribution.
#
# - Experiment: It’s important to experiment with the degree of under- and oversampling as well as weighting to optimize balanced learning.
#
#
# By applying these resampling strategies, the data balance improves, which can help stabilize metrics like mAP during fine-tuning and improve overall model robustness across all classes.To address the extreme class imbalance in your training dataset, a common solution is to use sampling techniques to balance the dataset:
#
# - Undersampling: Reduce samples from majority classes by randomly removing some instances or using informed methods like Near Miss or Tomek Links, which selectively remove samples from majority classes near minority class boundaries. This prevents the model from overwhelming bias towards large classes.
#
# - Oversampling: Increase samples from minority classes by duplicating instances or generating synthetic samples using methods like SMOTE or Perceptual Borderline SMOTE, which interpolate between minority samples to create new, plausible instances.
#
# - Hybrid methods: Combine undersampling of large classes with oversampling of small classes to maintain data diversity and balance effectively.
#
# - Class weighting: Alternatively, or in addition, use class-weighted loss functions to penalize misclassification of minority classes more heavily without changing data distribution.
#
# It's recommended to experiment with these approaches and their parameters, aiming for a balanced representation that helps the model learn all classes well and stabilizes performance metrics like mAP during fine-tuning.
#
#
# ### how to apply class weight in transformers
# To apply class weights in fine-tuning transformers with PyTorch, you typically define a weighted loss function that penalizes misclassification of underrepresented classes more heavily. Here's how you can do it:
#
# ### How to Apply Class Weights in Transformers (PyTorch)
# Calculate class weights: Create a tensor of class weights inversely proportional to class frequencies.
#
# - Use weighted loss function: Pass the class weights to PyTorch's nn.CrossEntropyLoss(weight=class_weights). This makes the loss sensitive to class imbalance.
#
# Integrate with Hugging Face Trainer:
#
# Subclass the Trainer class.
#
# Override the compute_loss method to apply the weighted loss function instead of the default one.
#
# Example Code
# python
# import torch
# from torch import nn
# from transformers import Trainer
#
# # Define class weights as a torch tensor, for example:
# class_weights = torch.tensor([0.1, 0.3, 0.6], device='cuda')  # Replace with actual weights
#
# # Custom Trainer to use weighted loss
# ```
# class CustomTrainer(Trainer):
#     def compute_loss(self, model, inputs, return_outputs=False):
#         labels = inputs.get("labels")
#         outputs = model(**inputs)
#         logits = outputs.get('logits')
#         loss_fct = nn.CrossEntropyLoss(weight=class_weights)
#         loss = loss_fct(logits.view(-1, model.config.num_labels), labels.view(-1))
#         return (loss, outputs) if return_outputs else loss
# ```
#
# This approach lets the transformer model focus more on minority classes by increasing their contribution to the loss during training. The class weights tensor should be calculated based on class frequencies from your dataset.
#
# This method is the standard way to apply class weights during transformer fine-tuning in PyTorch and Hugging Face Trainer.

# %%
sampleValue =  14802 //5
sampleValue
# Out:
# 2960

# %%
# median value = 50 
(trainDF["label"].value_counts() > sampleValue).sum() # number of class > 50 counts
# Out:
# np.int64(3)

# %% [markdown]
# ## Use Mix Undersample and Oversample Improve performance

# %%
# Assume df is your DataFrame and 'label' is your class column
desired_count = sampleValue #50
def resample_group_mix(group):
    '''
    Resample with hybird undersample and Oversample
    '''
    n = len(group)
    if n > desired_count:
        # Undersample if more than desired_count
        return group.sample(n=desired_count, random_state=42)
    elif n < desired_count:
        # Oversample with replacement if less than desired_count
        return group.sample(n=desired_count, replace=True, random_state=42)
    else:
        # Keep as is if exactly desired_count
        return group

# %%
# conditional oversample 
oversample_count = 1000
def resample_group_oversample(group):
    '''
    Resample with condition Oversample , keep major
    '''
    n = len(group)
    if n < oversample_count:
        # Oversample with replacement if less than desired_count
        return group.sample(n=oversample_count, replace=True, random_state=42)
    else:
        # Keep as is if exactly desired_count
        return group

# %%
#

# Group by class and sample min(desired_count, current_count) from each class
# trainDF_balanced = trainDF.groupby('label', group_keys=False).apply(lambda x: x.sample(n=min(len(x), desired_count), random_state=42))
trainDF_balanced = trainDF.groupby('label', group_keys=False).apply(resample_group_oversample)

print(trainDF_balanced['label'].value_counts())
# Out:
# label
# 37    14802
# 36     6542
# 64     5265
# 13     1446
# 0      1000
#       ...
# 58     1000
# 60     1000
# 61     1000
# 62     1000
# 63     1000
# Name: count, Length: 65, dtype: int64
# /tmp/ipykernel_3863/4246594355.py:5: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   trainDF_balanced = trainDF.groupby('label', group_keys=False).apply(resample_group_oversample)

# %%
trainDF_balanced['label'].value_counts()[:55]
# Out:
# label
# 37    14802
# 36     6542
# 64     5265
# 13     1446
# 0      1000
# 5      1000
# 1      1000
# 3      1000
# 2      1000
# 8      1000
# 9      1000
# 11     1000
# 10     1000
# 12     1000
# 6      1000
# 7      1000
# 4      1000
# 17     1000
# 18     1000
# 19     1000
# 20     1000
# 21     1000
# 22     1000
# 23     1000
# 24     1000
# 25     1000
# 26     1000
# 27     1000
# 28     1000
# 29     1000
# 14     1000
# 15     1000
# 16     1000
# 32     1000
# 31     1000
# 30     1000
# 34     1000
# 35     1000
# 38     1000
# 39     1000
# 33     1000
# 41     1000
# 42     1000
# 43     1000
# 44     1000
# 45     1000
# 46     1000
# 47     1000
# 40     1000
# 48     1000
# 49     1000
# 51     1000
# 50     1000
# 53     1000
# 54     1000
# Name: count, dtype: int64

# %%
trainDF_balanced['label'].value_counts().plot(kind="bar", title="Distribution Label");

# %%
trainDF_balanced = trainDF_balanced.reset_index(drop=True)

# %%
trainDF_balanced
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 0       14350       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 1       25280       33472                     \( \frac{1}{3}+\frac{2}{5}= \)
# 2       11228       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 3        2945       31772  What fraction of the shape is not shaded? Give...
# 4       16143       32829        \( 2 y=24 \) What is the value of \( y \) ?
# ...       ...         ...                                                ...
# 89050   36262      109465  The probability of an event occurring is \( 0....
# 89051   36271      109465  The probability of an event occurring is \( 0....
# 89052   36274      109465  The probability of an event occurring is \( 0....
# 89053   36276      109465  The probability of an event occurring is \( 0....
# 89054   36277      109465  The probability of an event occurring is \( 0....
#
#                  MC_Answer                                 StudentExplanation  \
# 0                  \( 9 \)  This is because youu can time both 10 and 15 t...
# 1      \( \frac{11}{30} \)  i know this because a common denominator is 15...
# 2                  \( 3 \)                    i divided by 3 and timesed by 2
# 3        \( \frac{3}{9} \)               3 outt of 9 are not-shaded. also 1/3
# 4                 \( 22 \)  24%2=12\n12  so the answer is 12 because the 2...
# ...                    ...                                                ...
# 89050               Likely  this is because a 9 out of 10 chance means tha...
# 89051               Likely  this is your answer because 1 would be certain...
# 89052               Likely  u can use the process of elimination because c...
# 89053               Likely     very high probability however it's not certain
# 89054               Likely  we should use likely because we dont know for ...
#
#             Category Misconception            target  label  is_correct
# 0      False_Correct            NA  False_Correct:NA      0           0
# 1      False_Correct            NA  False_Correct:NA      0           0
# 2      False_Correct            NA  False_Correct:NA      0           0
# 3      False_Correct            NA  False_Correct:NA      0           0
# 4      False_Correct            NA  False_Correct:NA      0           0
# ...              ...           ...               ...    ...         ...
# 89050   True_Neither            NA   True_Neither:NA     64           1
# 89051   True_Neither            NA   True_Neither:NA     64           1
# 89052   True_Neither            NA   True_Neither:NA     64           1
# 89053   True_Neither            NA   True_Neither:NA     64           1
# 89054   True_Neither            NA   True_Neither:NA     64           1
#
# [89055 rows x 10 columns]

# %%
trainDF_balanced.isnull().sum() # null checking
# Out:
# row_id                0
# QuestionId            0
# QuestionText          0
# MC_Answer             0
# StudentExplanation    0
# Category              0
# Misconception         0
# target                0
# label                 0
# is_correct            0
# dtype: int64

# %% [markdown]
# ### Load LLM Model and Tokenizer

# %%
clearMemory()

# %%
# !pip install triton==3.0.0
import trl
trl.__version__
# Out:
# '0.19.1'

# %%
import triton

triton.__version__
# Out:
# '3.3.0'

# %%
# !pip install bitsandbytes==0.46.1

# %%
import bitsandbytes
bitsandbytes.__version__
# Out:
# '0.47.0'

# %%
import accelerate
accelerate.__version__
# Out:
# '1.10.1'

# %%
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen3ForCausalLM(
#       (model): Qwen3Model(
#         (embed_tokens): Embedding(151936, 2560, padding_idx=151654)
#         (layers): ModuleList(
#           (0-35): 36 x Qwen3DecoderLayer(
#             (self_attn): Qwen3Attention(
#               (q_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear(
#                 (base_layer): Linear(in_features=4096, out_features=2560, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2560, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#               (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): Qwen3MLP(
#               (gate_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=9728, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=9728, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2560, out_features=9728, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2560, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=9728, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=9728, out_features=2560, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=9728, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=2560, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#             (post_attention_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#           )
#         )
#         (norm): Qwen3RMSNorm((2560,), eps=1e-06)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=2560, out_features=151936, bias=False)
#     )
#   )
# )

# %%
if CFG.DeepEval:
    from deepeval.models.base_model import DeepEvalBaseLLM
    from deepeval.test_case import LLMTestCase, LLMTestCaseParams
    from deepeval.metrics import GEval
    # from deepeval import evaluate
    from deepeval.metrics import AnswerRelevancyMetric
    # from deepeval.benchmarks import MMLU, HellaSwag, HumanEval,TruthfulQA
    # from deepeval.benchmarks.tasks import HumanEvalTask, HellaSwagTask, MMLUTask, TruthfulQATask
    # from deepeval.benchmarks.modes import TruthfulQAMode

# %% [markdown]
# ## Prepare Training Dataset

# %%
# Random Resample Dataset
# trainDF = trainDF.sample(frac=1.0, replace=True)
# trainDF = trainDF.reset_index(drop=True)
# trainDF

trainDF_balanced= trainDF_balanced.sample(frac=1.0, replace=True)
trainDF_balanced = trainDF_balanced.reset_index(drop=True)
trainDF_balanced
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 0       29039       76870  This is part of a regular polygon. How many si...
# 1       11223       31778  \( \frac{A}{10}=\frac{9}{15} \) What is the va...
# 2       26739       33474  Sally has \( \frac{2}{3} \) of a whole cake in...
# 3       28801       76870  This is part of a regular polygon. How many si...
# 4       29189       76870  This is part of a regular polygon. How many si...
# ...       ...         ...                                                ...
# 89050   27435       33474  Sally has \( \frac{2}{3} \) of a whole cake in...
# 89051   33117       91695  Dots have been arranged in these patterns: [Im...
# 89052   30793       89443  What number belongs in the box?\n\(\n(-8)-(-5)...
# 89053   23029       33471  A bag contains \( 24 \) yellow and green balls...
# 89054   19591       32833               Calculate \( \frac{2}{3} \times 5 \)
#
#                                   MC_Answer  \
# 0                                   \( 5 \)
# 1                                   \( 3 \)
# 2      \( \frac{1}{3} \times \frac{2}{3} \)
# 3                                  \( 10 \)
# 4                                   \( 6 \)
# ...                                     ...
# 89050         \( \frac{2}{3}-\frac{1}{3} \)
# 89051                              \( 22 \)
# 89052                              \( -3 \)
# 89053                               \( 9 \)
# 89054                    \( \frac{2}{15} \)
#
#                                       StudentExplanation             Category  \
# 0      144 times 5 is 720 meaning it will add up to 7...  False_Misconception
# 1      i did 15 by 2 because 30 is the lowest comman ...        False_Correct
# 2      i think this because if there is 2/3 in the fr...   True_Misconception
# 3                each interior angle in a decagon = 144°         True_Correct
# 4             I believe a regular polygon has six sides.  False_Misconception
# ...                                                  ...                  ...
# 89050  because robert is eating it so it will go so i...  False_Misconception
# 89051  this is because if u work out how much the seq...        False_Neither
# 89052  i answered d because if you take away -5 from ...         True_Correct
# 89053                24 divided by 8 is 3 and 3 x 3 is 9  False_Misconception
# 89054  since if you change 5 to 1/5 it is 3 multiplie...  False_Misconception
#
#         Misconception                              target  label  is_correct
# 0            Interior        False_Misconception:Interior     15           0
# 1                  NA                    False_Correct:NA      0           0
# 2         Subtraction      True_Misconception:Subtraction     57           1
# 3                  NA                     True_Correct:NA     37           1
# 4          Definition      False_Misconception:Definition      6           0
# ...               ...                                 ...    ...         ...
# 89050     Subtraction     False_Misconception:Subtraction     26           0
# 89051              NA                    False_Neither:NA     36           0
# 89052              NA                     True_Correct:NA     37           1
# 89053  Wrong_fraction  False_Misconception:Wrong_fraction     34           0
# 89054       Inversion       False_Misconception:Inversion     17           0
#
# [89055 rows x 10 columns]

# %%
PROMPT_FORMAT1 = """\
You are an expert in identifying math misconceptions from student explanations.

Question: {QuestionText}
Answer: {MC_Answer}
Correct: {Correct}
Student Explanation: {StudentExplanation}

Identify the specific type of math misconception in the student's explanation.
Give a short, clear label for the misconception.
"""

PROMPT_FORMAT2 = """\
You are an expert educational diagnostician specializing in identifying students' math misconceptions from their written explanations.
Your task is to analyze the student's explanation and classify the specific type of misconception they demonstrate.

Question: {QuestionText}
Answer: {MC_Answer}
Correct: {Correct}
Student Explanation: {StudentExplanation}

Based on the information above, identify and label the underlying math misconception in the student's explanation.
Provide a clear and concise classification of the misconception type.
"""

PROMPT_FORMAT3 = """\
You are an expert in analyzing students' answers to math problems and identifying specific types of misunderstandings.
Given the following information, classify the student's misunderstanding.

Question: {QuestionText}
Answer: {MC_Answer}
Correct: {Correct}
Student Explanation: {StudentExplanation}

Please determine the type of misunderstanding the student has.
"""

PROMPT_FORMAT4 = """\
You are a specialist in identifying the types of misunderstandings that arise from students’ answers to math problems.
Based on the information provided below, please determine what kind of misunderstanding the student has.

Question: {QuestionText}
Answer: {MC_Answer}
Correct: {Correct}
Student Explanation: {StudentExplanation}
"""

# %%
# def generateTrainContent(row):
#     x= "True"
#     if not row["is_correct"]:
#         x= "False"
#     return (
#            f"Question: {row['QuestionText']}\n"
#            f"Answer: {row['MC_Answer']}\n"
#            f"Correct: {x}\n"
#            f"Student Explanation: {row['StudentExplanation']}"
#     )

def generateTrainContent(row):
    x= "True"
    if not row["is_correct"]:
        x= "False"
    return PROMPT_FORMAT3.format(
        QuestionText=row['QuestionText'],
        MC_Answer=row['MC_Answer'],
        Correct=x,
        StudentExplanation=row['StudentExplanation']
        
    )
    # return (
    #        f"Question: {row['QuestionText']}\n"
    #        f"Answer: {row['MC_Answer']}\n"
    #        f"Correct: {x}\n"
    #        f"Student Explanation: {row['StudentExplanation']}"
    # )

# %%
# trainDF["LLM_Content"]= trainDF.apply(generateTrainContent, axis=1)
trainDF_balanced["LLM_Content"] = trainDF_balanced.apply(generateTrainContent, axis=1)

# %%
testDF["LLM_Content"]= testDF.apply(generateTrainContent, axis=1)

# %%
# print one of example
print(trainDF_balanced["LLM_Content"].values[0])
# Out:
# You are an expert in analyzing students' answers to math problems and identifying specific types of misunderstandings.
# Given the following information, classify the student's misunderstanding.
#
# Question: This is part of a regular polygon. How many sides does it have? [Image: A diagram showing an obtuse angle labelled 144 degrees]
# Answer: \( 5 \)
# Correct: False
# Student Explanation: 144 times 5 is 720 meaning it will add up to 722 in total meaning the object has 5 sides.
#
# Please determine the type of misunderstanding the student has.

# %%
print(testDF["LLM_Content"].values[0])
# Out:
# You are an expert in analyzing students' answers to math problems and identifying specific types of misunderstandings.
# Given the following information, classify the student's misunderstanding.
#
# Question: What fraction of the shape is not shaded? Give your answer in its simplest form. [Image: A triangle split into 9 equal smaller triangles. 6 of them are shaded.]
# Answer: \( \frac{1}{3} \)
# Correct: True
# Student Explanation: I think that 1/3 is the answer, as it's the simplest form of 3/9.
#
# Please determine the type of misunderstanding the student has.

# %% [markdown]
# ## lenght of the LLM conntent

# %%
# trainDF["Length"] = trainDF["LLM_Content"].str.len()
trainDF_balanced["Length"] = [len(tokenizer.encode(t, truncation=False)) for t in trainDF_balanced["LLM_Content"]]

trainDF_balanced["Length"].describe()
# Out:
# count    89055.000000
# mean       110.827275
# std         20.999533
# min         69.000000
# 25%         96.000000
# 50%        108.000000
# 75%        123.000000
# max        363.000000
# Name: Length, dtype: float64

# %%
trainDF_balanced["Length"].plot(kind='hist', bins=50, subplots=True,sharex=True,sharey=True, title='LLM Content Length Distribution');

# %%
MAX_LEN = 256 #512
L = (np.array(trainDF_balanced["Length"])>MAX_LEN).sum()
print(f"There are {L} train sample(s) with more than {MAX_LEN} tokens")
# Out:
# There are 2 train sample(s) with more than 256 tokens

# %% [markdown]
# ### MAX window size 256 is suitable for training

# %% [markdown]
# ## Create Dataset

# %%
len(trainDF_balanced) , round(len(trainDF_balanced) * 0.85) # check train data size
# Out:
# (89055, 75697)

# %%
totalTrainSize= len(trainDF_balanced)
totalTrainSize
# Out:
# 89055

# %%
setMaxTrainData = totalTrainSize - CFG.valDatasetSize
setMaxTrainData
# Out:
# 89005

# %% [markdown]
# ### Create Dataset for Train/Validation

# %%
# tempTrainDF = trainDF[:setMaxTrainData]
# tempValDF = trainDF[setMaxTrainData:] 


# tempTrainDF , tempValDF = train_test_split(trainDF_balanced , stratify= trainDF["is_correct"], test_size=CFG.test_size, random_state=42)
tempTrainDF , tempValDF = train_test_split(trainDF_balanced ,  test_size=CFG.test_size, random_state=42)

# %%
tempTrainDF
# Out:
#        row_id  QuestionId                                       QuestionText  \
# 71553   26203       33472                     \( \frac{1}{3}+\frac{2}{5}= \)
# 23436   29881       89443  What number belongs in the box?\n\(\n(-8)-(-5)...
# 46187   21212       32835                      Which number is the greatest?
# 15484   17552       32833               Calculate \( \frac{2}{3} \times 5 \)
# 43542   20364       32835                      Which number is the greatest?
# ...       ...         ...                                                ...
# 6265    25283       33472                     \( \frac{1}{3}+\frac{2}{5}= \)
# 54886   33191       91695  Dots have been arranged in these patterns: [Im...
# 76820   19231       32833               Calculate \( \frac{2}{3} \times 5 \)
# 860      1416       31772  What fraction of the shape is not shaded? Give...
# 15795   35502      104665  It takes \( 3 \) people a total of \( 192 \) h...
#
#                  MC_Answer                                 StudentExplanation  \
# 71553    \( \frac{3}{8} \)       i think it is that because 1+2=3 then 3+5=8.
# 23436            \( -13 \)             if you sdd 5 and 8 its 13 but with a -
# 46187            \( 6.2 \)  d because it has a 6 the same as a but it also...
# 15484  \( 3 \frac{1}{3} \)             i put 1 over 5 timesd it and got thayt
# 43542            \( 6.2 \)                   6 is bigger than decimal numbers
# ...                    ...                                                ...
# 6265   \( \frac{11}{30} \)  i think it is 11/30 because if you convert it ...
# 54886             \( 26 \)  3 dots are added in 1 column and 1 dot is adde...
# 76820   \( \frac{2}{15} \)  Because I times the bottom number by whole num...
# 860      \( \frac{1}{3} \)  There are 9 triangles in all and three are sha...
# 15795       \( 64 \) hours  because you do 3 x 4 is 12 on one side and the...
#
#                   Category                           Misconception  \
# 71553  False_Misconception                           Adding_across
# 23436  False_Misconception                                 Tacking
# 46187   True_Misconception                        Longer_is_bigger
# 15484   True_Misconception                               Inversion
# 43542   True_Misconception                    Whole_numbers_larger
# ...                    ...                                     ...
# 6265   False_Misconception  Incorrect_equivalent_fraction_addition
# 54886         True_Correct                                      NA
# 76820  False_Misconception                               Inversion
# 860     True_Misconception                              Incomplete
# 15795  False_Misconception                               Base_rate
#
#                                                   target  label  is_correct  \
# 71553                  False_Misconception:Adding_across      1           0
# 23436                        False_Misconception:Tacking     28           0
# 46187                True_Misconception:Longer_is_bigger     51           1
# 15484                       True_Misconception:Inversion     49           1
# 43542            True_Misconception:Whole_numbers_larger     61           1
# ...                                                  ...    ...         ...
# 6265   False_Misconception:Incorrect_equivalent_fract...     14           0
# 54886                                    True_Correct:NA     37           1
# 76820                      False_Misconception:Inversion     17           0
# 860                        True_Misconception:Incomplete     47           1
# 15795                      False_Misconception:Base_rate      4           0
#
#                                              LLM_Content  Length
# 71553  You are an expert in analyzing students' answe...      99
# 23436  You are an expert in analyzing students' answe...      95
# 46187  You are an expert in analyzing students' answe...      88
# 15484  You are an expert in analyzing students' answe...      95
# 43542  You are an expert in analyzing students' answe...      73
# ...                                                  ...     ...
# 6265   You are an expert in analyzing students' answe...     115
# 54886  You are an expert in analyzing students' answe...     143
# 76820  You are an expert in analyzing students' answe...      88
# 860    You are an expert in analyzing students' answe...     126
# 15795  You are an expert in analyzing students' answe...     133
#
# [88164 rows x 12 columns]

# %%
tempTrainDF["label"].value_counts().plot(kind="bar", title="Class Distribution");

# %%
tempValDF.describe()
# Out:
#              row_id     QuestionId       label  is_correct      Length
# count    891.000000     891.000000  891.000000  891.000000  891.000000
# mean   20323.021324   49425.079686   34.774411    0.531987  110.224467
# std    10169.096768   27238.149842   17.174572    0.499256   20.370366
# min      107.000000   31772.000000    0.000000    0.000000   70.000000
# 25%    12936.000000   31778.000000   23.000000    0.000000   96.000000
# 50%    20730.000000   32835.000000   37.000000    1.000000  108.000000
# 75%    29022.500000   76870.000000   47.000000    1.000000  120.000000
# max    36665.000000  109465.000000   64.000000    1.000000  183.000000

# %%
# Convert to Hugging Face Dataset for training dataset
COLS = ['LLM_Content','label']

trainDataset = Dataset.from_pandas(tempTrainDF[COLS], split="train")
valDataset = Dataset.from_pandas(tempValDF[COLS], split="test")
testDataset = Dataset.from_pandas(testDF, split="test")
subDataset = Dataset.from_pandas(sample, split="test") # submit dataset

# trainDataset = Dataset.from_pandas(tempTrainDF, split="train")
# valDataset = Dataset.from_pandas(tempValDF, split="test")
# subDataset = Dataset.from_pandas(sample, split="test") # submit dataset

# %%
trainDataset
# Out:
# Dataset({
#     features: ['LLM_Content', 'label', '__index_level_0__'],
#     num_rows: 88164
# })

# %%
testDataset
# Out:
# Dataset({
#     features: ['row_id', 'QuestionId', 'QuestionText', 'MC_Answer', 'StudentExplanation', 'is_correct', 'LLM_Content'],
#     num_rows: 3
# })

# %%
subDataset
# Out:
# Dataset({
#     features: ['row_id', 'Category:Misconception'],
#     num_rows: 3
# })

# %%
# for GPU only
# !nvidia-smi
# Out:
# Sun Oct  5 09:34:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.28.03              Driver Version: 560.28.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080        Off |   00000000:01:00.0  On |                  N/A |
# |  0%   49C    P8             29W /  370W |   11657MiB /  12288MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1963      C   /opt/conda/bin/python3                          0MiB |
# |    0   N/A  N/A      2180      C   /opt/conda/bin/python3                          0MiB |
# |    0   N/A  N/A      2817      C   /opt/conda/bin/python3                          0MiB |
# +-----------------------------------------------------------------------------------------+
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
del tempTrainDF 
del tempValDF

# %%
datasetDict = DatasetDict({
    "train" : trainDataset,
    "val"  : valDataset
    
})
datasetDict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['LLM_Content', 'label', '__index_level_0__'],
#         num_rows: 88164
#     })
#     val: Dataset({
#         features: ['LLM_Content', 'label', '__index_level_0__'],
#         num_rows: 891
#     })
# })

# %%
datasetDict["train"]
# Out:
# Dataset({
#     features: ['LLM_Content', 'label', '__index_level_0__'],
#     num_rows: 88164
# })

# %%
def tokenizeFunc(batch):
    return tokenizer(batch["LLM_Content"],  max_length=CFG.maxLength, padding='max_length', truncation=True)

# %%
datasetDict = datasetDict.map(tokenizeFunc, batched=True)
# Out:
# Map:   0%|          | 0/88164 [00:00<?, ? examples/s]
# Map:   0%|          | 0/891 [00:00<?, ? examples/s]

# %%
datasetDict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['LLM_Content', 'label', '__index_level_0__', 'input_ids', 'attention_mask'],
#         num_rows: 88164
#     })
#     val: Dataset({
#         features: ['LLM_Content', 'label', '__index_level_0__', 'input_ids', 'attention_mask'],
#         num_rows: 891
#     })
# })

# %%
datasetDict = datasetDict.rename_column("label", "labels")  # change name to labels

# %%
datasetDict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['LLM_Content', 'labels', '__index_level_0__', 'input_ids', 'attention_mask'],
#         num_rows: 88164
#     })
#     val: Dataset({
#         features: ['LLM_Content', 'labels', '__index_level_0__', 'input_ids', 'attention_mask'],
#         num_rows: 891
#     })
# })

# %%
testDict = DatasetDict({
    "test": testDataset
    
})
testDict
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['row_id', 'QuestionId', 'QuestionText', 'MC_Answer', 'StudentExplanation', 'is_correct', 'LLM_Content'],
#         num_rows: 3
#     })
# })

# %%
submitDict = DatasetDict({
    "test": subDataset
    # "test": subDataset
    
})
submitDict
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['row_id', 'Category:Misconception'],
#         num_rows: 3
#     })
# })

# %%
# Evaluation Metrics
def compute_metric(eval_pred):
    logits , labels = eval_pred
    predictions = np.argmax(logits, axis=-1)  # for mult-class
    acc = (predictions == labels).mean()
    f1score  =  f1_score(labels, predictions, average='weighted', zero_division=1)
    recallScore = recall_score(labels, predictions,  average='weighted', zero_division=1)
    precision = precision_score(labels, predictions,  average='weighted', zero_division=1)
    
    # for map@3
    top3_preds = np.argsort(logits, axis=-1)[:, -3:]
    match = (top3_preds == labels[:, None])

    # Compute MAP@3 manually
    map3 = 0
    for i in range(len(labels)):
        if match[i, 0]:
            map3 += 1.0
        elif match[i, 1]:
            map3 += 1.0 / 2
        elif match[i, 2]:
            map3 += 1.0 / 3
    map3Score = map3 / len(labels)
    # map3List.append(map3Score)
    
    return {"accuracy": acc , "recall":  recallScore,  "precision":precision, 'f1-score': f1score ,
             "map_3":map3Score}

# %% [markdown]
# ## LoRA fine tuing

# %%
# lora_config = LoraConfig(
#         r=16,
#         lora_alpha=32,
#         task_type="SEQ_CLS",  # for Sequence Classification
#         # task_type="CAUSAL_LM", # for generative task
#         bias="none",
#         target_modules = ["q_proj", "o_proj", "k_proj", "v_proj",
#                       "gate_proj", "up_proj", "down_proj"],
#         lora_dropout= CFG.DROPOUT,
#     )

# %%
# Creat Lora Model
# model = get_peft_model(model, lora_config)

# %%
model.print_trainable_parameters()
# Out:
# trainable params: 33,030,144 || all params: 4,055,498,240 || trainable%: 0.8145

# %%
import trl
trl.__version__
# Out:
# '0.19.1'

# %%
 CFG.maxEpoch
# Out:
# 0.005

# %%
N_SAMPLES = len(datasetDict["train"])  # Use train_df after the split
STEPS_PER_EPOCH = (N_SAMPLES // CFG.per_device_train_batch_size ) #* CFG.maxEpoch
VAL_STEPS_PER_EPOCH = len(datasetDict["val"]) // CFG.per_device_eval_batch_size
TOTAL_STEPS = int(STEPS_PER_EPOCH * CFG.maxEpoch)
NUM_WARMUP_STEPS = int(TOTAL_STEPS * 0.1)

print(f'BATCH_SIZE: {CFG.per_device_train_batch_size}, N_SAMPLES: {N_SAMPLES}, STEPS_PER_EPOCH: {STEPS_PER_EPOCH}')
print(f'NUM_WARMUP_STEPS: {NUM_WARMUP_STEPS}, TOTAL_STEPS: {TOTAL_STEPS}')
print(f"Val Step per epoch: {VAL_STEPS_PER_EPOCH}")
# Out:
# BATCH_SIZE: 8, N_SAMPLES: 88164, STEPS_PER_EPOCH: 11020
# NUM_WARMUP_STEPS: 5, TOTAL_STEPS: 55
# Val Step per epoch: 111

# %%
# import deepspeed
# deepspeed.__version__

# %% [markdown]
# ## STF Trainer Parameter

# %%
from trl import SFTTrainer, SFTConfig
torch_dtype = model.dtype
trainArg = SFTConfig(
    output_dir= "lora_fine_tune", #"kaggle/working",
    # max_length= CFG.maxLength, # old version trl
    max_seq_length = CFG.maxLength, # new version trl
    per_device_train_batch_size =CFG.per_device_train_batch_size,
    per_device_eval_batch_size = CFG.per_device_eval_batch_size,
    gradient_accumulation_steps = CFG.gradient_accumulation_steps,
    eval_strategy= "steps",
    save_strategy= "steps",
    warmup_steps= NUM_WARMUP_STEPS, #CFG.warmup_steps,
    max_steps = TOTAL_STEPS,  #CFG.maxTrainStep, # set max train step size
    learning_rate=CFG.learning_rate,
    lr_scheduler_type= "linear", #"cosine",
    save_total_limit=2,
    fp16=True if torch_dtype == torch.float16 else False,   # use float16 precision ,  # INFER WITH FP16 BECAUSE KAGGLE IS T4 GPU
    bf16=True if torch_dtype == torch.bfloat16 else False,  # use bfloat16 precision, TRAIN WITH BF16 IF LOCAL GPU IS NEWER GPU  
    # fp16=True,
    logging_steps= CFG.evalSteps,
    eval_steps = CFG.evalSteps,
    optim="adamw_8bit",  #"paged_adamw_8bit",
    report_to = CFG.reportTo,
    do_eval=True,                # Perform evaluation at the end of training
    max_grad_norm=1.0,
    # weight_decay=0.01,
    metric_for_best_model="map_3",
    greater_is_better=True,
    # memory optimial (reduce GPU memory but slowdown train speed )
    # gradient_checkpointing=True,
    # gradient_checkpointing_kwargs={'use_reentrant':False}, # for Mulitple -GPU
    load_best_model_at_end=True,

    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 12
#       1 from trl import SFTTrainer, SFTConfig
#       2 torch_dtype = model.dtype
#       3 trainArg = SFTConfig(
#       4     output_dir= "lora_fine_tune", #"kaggle/working",
#       5     # max_length= CFG.maxLength, # old version trl
#       6     max_seq_length = CFG.maxLength, # new version trl
#       7     per_device_train_batch_size =CFG.per_device_train_batch_size,
#       8     per_device_eval_batch_size = CFG.per_device_eval_batch_size,
#       9     gradient_accumulation_steps = CFG.gradient_accumulation_steps,
#      10     eval_strategy= "steps",
#      11     save_strategy= "steps",
# ---> 12     warmup_steps= NUM_WARMUP_STEPS, #CFG.warmup_steps,
#      13     max_steps = TOTAL_STEPS,  #CFG.maxTrainStep, # set max train step size
#      14     learning_rate=CFG.learning_rate,
#      15     lr_scheduler_type= "linear", #"cosine",
#      16     save_total_limit=2,
#      17     fp16=True if torch_dtype == torch.float16 else False,   # use float16 precision ,  # INFER WITH FP16 BECAUSE KAGGLE IS T4 GPU
#      18     bf16=True if torch_dtype == torch.bfloat16 else False,  # use bfloat16 precision, TRAIN WITH BF16 IF LOCAL GPU IS NEWER GPU
#      19     # fp16=True,
#      20     logging_steps= CFG.evalSteps,
#      21     eval_steps = CFG.evalSteps,
#      22     optim="adamw_8bit",  #"paged_adamw_8bit",
#      23     report_to = CFG.reportTo,
#      24     do_eval=True,                # Perform evaluation at the end of training
#      25     max_grad_norm=1.0,
#      26     # weight_decay=0.01,
#      27     metric_for_best_model="map_3",
#      28     greater_is_better=True,
#      29     # memory optimial (reduce GPU memory but slowdown train speed )
#      30     # gradient_checkpointing=True,
#      31     # gradient_checkpointing_kwargs={'use_reentrant':False}, # for Mulitple -GPU
#      32     load_best_model_at_end=True,
#      33
#      34
#      35 )
#
# NameError: name 'NUM_WARMUP_STEPS' is not defined

# %%
trainArg.bf16
# Out:
# True

# %%
from transformers import DataCollatorWithPadding

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

trainer= SFTTrainer(
    model=model,
    train_dataset=datasetDict["train"],
    # eval_dataset = datasetDict["val"],
    args=trainArg,
    # peft_config = lora_config,
    # formatting_func=formatFuct,
    data_collator = data_collator, 
    # compute_metrics= compute_metric,
    
    
)

# %%
# Fix Batch size >1 , not define pad token id issues
eos_token_id=tokenizer.eos_token_id
model.config.use_cache=False
model.config.pad_token_id = tokenizer.pad_token_id

# %%
clearMemory() # clear memory before training

# %%
gpuMemory()
# Out:
# GPU = NVIDIA GeForce RTX 3080. Max memory = 11.636 GB.
# 2.691 GB of memory reserved.
# 2.691

# %%
# %%time
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[191], line 2
#       1 # %%time
# ----> 2 trainer.train()
#
# File /opt/conda/lib/python3.11/site-packages/transformers/trainer.py:2145, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2137 # do_train is not a reliable argument, as it might not be set and .train() still called, so
#    2138 # the following is a workaround:
#    2139 if (
#    2140     (args.fp16_full_eval or args.bf16_full_eval)
#    2141     and not args.do_train
#    2142     and not self.is_model_parallel
#    2143     and self.model_init is None
#    2144 ):
# -> 2145     self._move_model_to_device(self.model, args.device)
#    2147 if "model_path" in kwargs:
#    2148     resume_from_checkpoint = kwargs.pop("model_path")
#
# File /opt/conda/lib/python3.11/site-packages/transformers/trainer.py:895, in Trainer._move_model_to_device(self, model, device)
#     894 def _move_model_to_device(self, model, device):
# --> 895     model = model.to(device)
#     896     # Moving a model to an XLA device disconnects the tied weights, so we have to retie them.
#     897     if self.args.parallel_mode == ParallelMode.TPU and hasattr(model, "tie_weights"):
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1355, in Module.to(self, *args, **kwargs)
#    1352         else:
#    1353             raise
# -> 1355 return self._apply(convert)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 915 (5 times)]
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:942, in Module._apply(self, fn, recurse)
#     938 # Tensors stored in modules are graph leaves, and we don't want to
#     939 # track autograd history of `param_applied`, so we have to use
#     940 # `with torch.no_grad():`
#     941 with torch.no_grad():
# --> 942     param_applied = fn(param)
#     943 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     945 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1348, in Module.to.<locals>.convert(t)
#    1346 except NotImplementedError as e:
#    1347     if str(e) == "Cannot copy out of meta tensor; no data!":
# -> 1348         raise NotImplementedError(
#    1349             f"{e} Please use torch.nn.Module.to_empty() instead of torch.nn.Module.to() "
#    1350             f"when moving module from meta to a different device."
#    1351         ) from None
#    1352     else:
#    1353         raise
#
# NotImplementedError: Cannot copy out of meta tensor; no data! Please use torch.nn.Module.to_empty() instead of torch.nn.Module.to() when moving module from meta to a different device.

# %%
model.save_pretrained("student-math-llm-Fine-tune") # for peft fine tuning model without trainer
# trainer.save_model("student-math-llm-Fine-tune") # save model with full trainer

# %%
# for generate downloadable zip file 
# !zip -r student-math-llm-Fine-tune.zip /kaggle/working/student-math-llm-Fine-tune # for peft

# %%
trainHistoryDF = pd.DataFrame(trainer.state.log_history)
trainHistoryDF

# %%
trainHistoryDF.columns

# %%
import matplotlib.pyplot as plt
trainloss = trainHistoryDF[~trainHistoryDF["loss"].isnull()]
valloss = trainHistoryDF[~trainHistoryDF["eval_loss"].isnull()]
plt.plot(trainloss["loss"], label="Train")
plt.plot(valloss["eval_loss"], label="Val")
plt.title("LLM loss")
plt.legend()
plt.show()

# %%
trainloss = trainHistoryDF[~trainHistoryDF["eval_accuracy"].isnull()]
plt.plot(trainloss["eval_accuracy"], label="Val Accuracy")
plt.title("Val Accuracy")
plt.legend()
plt.show()

# %%
trainloss = trainHistoryDF[~trainHistoryDF["eval_recall"].isnull()]
plt.plot(trainloss["eval_recall"], label="Val Recall")
plt.title("Val Recall")
plt.legend()
plt.show()

# %%
trainloss = trainHistoryDF[~trainHistoryDF["eval_precision"].isnull()]
plt.plot(trainloss["eval_precision"], label="Val Precision")
plt.title("Val Precision")
plt.legend()
plt.show()

# %%
trainloss = trainHistoryDF[~trainHistoryDF["eval_f1-score"].isnull()]
plt.plot(trainloss["eval_f1-score"], label="Val F1-Score")
plt.title("Val F1-Score")
plt.legend()
plt.show()

# %%
trainloss = trainHistoryDF[~trainHistoryDF["eval_map@3"].isnull()]
plt.plot(trainloss["eval_map@3"], label="MAP@3 Score")
plt.title("Val MAP@3")
plt.legend()
plt.show()

# %%
def testValDataset(ds, maxNumData=10):
    for i, data in enumerate(ds):
        if (i >= maxNumData):
            break
        print(f"Data {i}")
        newPrompt = data["LLM_Content"]
        with torch.no_grad():
             inputIds = tokenizer(newPrompt, return_tensors="pt").to(device)
             logits = model(**inputIds).logits
             print(f"Logits Dimension: {logits.shape}")
             probabilities = nn.functional.softmax(logits, dim=-1) # get probilitity
             print(f"Probailities : {probabilities}")
             classID =logits.argmax().item()
             print(f"Class ID type {type(classID)}")
             classTxt = le.inverse_transform([classID])[0]
             actualClassID = data['labels']
             # print(f"Actual ClassID : {actualClassID}")
             actualClass = le.inverse_transform([actualClassID])[0]
             # Top3 prediction
             # acc = (probabilities == actualClassID).mean()
             # f1score  =  f1_score(actualClassID, probabilities, average='weighted', zero_division=1)
             # recallScore = recall_score(actualClassID, probabilities,  average='weighted', zero_division=1)
             # precision = precision_score(actualClassID, probabilities,  average='weighted', zero_division=1)
            
             # # for map@3
             top3_preds = np.argsort(logits.to(torch.float32).cpu(), axis=-1)[:, -3:]
             top3 = top3_preds.flatten() # convert to 1D 
             print(f"Top3 ID : {top3}")
             # classTxtArray = le.inverse_transform(top3) # convert class ID to Label 
             match = (top3_preds == actualClassID)
                    
             # Compute MAP@3 manually
             map3 = 0
             for i in range(len([actualClassID])):
                if match[i, 0]:
                    map3 += 1.0
                elif match[i, 1]:
                    map3 += 1.0 / 2
                elif match[i, 2]:
                    map3 += 1.0 / 3
             map3Score = map3 / len([actualClassID])
        

        print(f"""Query: {newPrompt}
              Predict Class ID: {classID}
              Predict Text: {classTxt}
              Actual Class ID: {actualClassID}
              Actual Class Text: {actualClass}
             MAP@3 Score : {map3Score}""")
        print("-"*30)

# %%
testValDataset(datasetDict["val"], 20 )
